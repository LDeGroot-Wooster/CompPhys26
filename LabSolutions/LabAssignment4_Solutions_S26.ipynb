# %% [markdown]
# #### Name: Solutions

# %% [markdown]
# # PHYS 230 Lab Assignment 4
#
# ### Monday, January 29, 2024: Chapter 3.1-3.2
# - Graphing in python - Matplotlib PyPlot
# - Scatter plots

# %% [markdown]
# #### Start by importing any packages you need below (feel free to update as you go):

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Catch the errors! (20 pts - 5 pts each)
#
# **Please read directions carefully**
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. edit the problem cell with the corrected code so it will run [do not add a new cell] <br>
#     b. below the cell, add a new markdown cell that describes what was wrong with the code<br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
x=[1,2,6,8]
plot(x)

# %%
## corrected:

x=[1,2,6,8]
plt.plot(x)
plt.show()

# %% [markdown]
# #### Explanation:
#
# To plot this, we need to include that the `plot()` function comes from pyplot, which has been imported as `plt`

# %%
# instructions: make a plot of potential energy (E) of a 5 kg object given a range of heights (h) using circle markers
h = np.arange(1,10,20)
E = mg*h
plt.plot(h,E)

# %%
# corrected 
m = 5.0
g = 9.81
h = np.arange(1,10,0.5)
E = m*g*h
plt.plot(h,E, 'o')
plt.show()

# %% [markdown]
# #### explanation:
#
# In `np.arange()`, the last value is the step increment. Going by 20 steps will result in 0 elements in this array. Instead, to make 20 points, I switched the step size to 0.5 or you could use `np.linspace()` instead.
#
# Also, the mass needed to be defined and the calculation needed to include a `*` symbol for multiplication

# %%
theta = np.arange(0,90,10)
y = np.sin(theta)
plt.plot(theta,y, "points")
plt.xaxis('theta (degrees)')
plt.yaxis('sin(theta)')

# %%
# corrected

theta = np.arange(0,90,10)
y = np.sin(np.radians(theta))
plt.plot(theta,y, "o")
plt.xlabel('theta (degrees)')
plt.ylabel('sin(theta)')
plt.show()
# Out:
# Text(0, 0.5, 'sin(theta)')

# %% [markdown]
# #### explanation
#
# there are two main errors in this code
# 1) the `np.sin()` function requires theta in radians, but 0 - 90 would be in degrees. Use `np.radians()` to convert
# 2) to label the axes, you need to use `plt.xlabel` and `plt.ylabel` instead of `plt.axis`

# %%
a = np,linspace(0,100,50)
b = [1,2,3,4,5]
plt.scatter(a,b)

# %%
# corrected 

a = np.linspace(0,100,50)
b = range(50)
plt.scatter(a,b)
plt.show()

# %% [markdown]
# #### explanation
#
# The original array and list that were being plotted had different lengths. To make a scatter plot, the two variables must be the same length.

# %% [markdown]
# ## Short python snippets (10 pts - 5 pts each)
# Below each markdow cell, write a short python snippet to perform the indicated action; you will likely have to use google to find out how to perform some of these actions--this is deliberate on my part. Google and *stack overflow* are your friends.<br>
# Add a markdown cell to explain your thinking if this is needed.

# %% [markdown]
# 1. Create a list of 10 integers between 0 and 20 and plot them. (You should look up how to make it random!)

# %%
ran_list = [] # create empty list to append random integers to
# loop through 10 times to create list of random values 
for i in range(10):
    ran_val = random.randint(0,20) # creates random integer between 0 and 20
    ran_list.append(ran_val)

# plot the list 
plt.plot(ran_list, "o")
plt.show()

# %% [markdown]
# #### explanation:
#
# the `random.randint()` function will create a random integer between 0 and 20 (based on how I defined it). A loop must be done to append the new value to the list.
#
# Once that is completed, the 1D plot can easily be made.

# %% [markdown]
# 2. Make a scatter plot of two random independent arrays with 50 floating point values. Make all points larger & magenta.

# %%
# create random array of floats between 0 and 1 that is 1D with 50 points 
x_arr = np.random.rand(1,50)
#print(x_arr)
y_arr = 15.0*np.random.rand(1,50) #same as for x_arr but multiply by 15 to scale the range 
#print(y_arr)

# make scatter plot of each arrays, c and s are used to change color and size 
plt.scatter(x_arr, y_arr, c='m', s=200)
plt.show()

# %% [markdown]
# ### Write a script 1 (25 pts)
# #### Plotting a wave
#
# Write a code to do the following:
# - Create an array "t" that consists of float points between 0 and 20.
#     - Make sure to use enough points so that the graph looks smooth
# - Assuming this is wave data following the equation $y(t) = A\sin(\omega t)$, calculate $y$ using $\omega = 0.5$.
#     - Ask the user for the value of $A$.
# - Make a plot of $y$ vs $t$, making all points cyan diamond markers
# - Add a second set of data to your plot using cosine instead
#     - You choose the color and marker style (must be different from sine)
# - Don't forget to add a title and label your axes
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
# create 80 element array
t = np.linspace(0,20,200)

# calculate sine & cosine wave
omega = 1.0
A = float(input("Please give the amplitude of the wave: "))
y = A*np.sin(omega*t)
y_cos = A*np.cos(omega*t)


# plot the sine function 
plt.plot(t,y,'Dc')
plt.xlabel('time (s)')
plt.ylabel("Amplitude (m)")
plt.title("Sine and Cosine functions")
#plt.show()

# add the cosine function too
plt.plot(t,y_cos,'og')
plt.show()
# Out:
# Please give the amplitude of the wave: 5

# %% [markdown]
# #### Explanation:
#
# I found that 200 points was best in making these smooth - although slightly less and slightly more would be okay.
#
# I chose different markers and colors to show the difference between `sin` (cyan diamonds) and `cos` (green circles).

# %% [markdown]
# ### Write a script 2 (25 pts)
# #### Importing data for a scatter plot
#
# Write a code to do the following:
# - Download the file "circuit.txt" from Moodle
#     - The first column is of voltage, the second column is of current, and the third column is the uncertainty in the voltage
# - Make a scatter plot of the data so that if you knew how to do a linear fit to the data the slope would be resistance.
# - Label the axes with units and title the graph "Voltage and current in a resistor"
# - Add error bars to the plot for the uncertainty in the voltage
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
# import the data & define
data = np.loadtxt("circuit.txt", float)
voltage = data[:,0]
current = data[:,1]
voltage_unc=data[:,2]

# plot voltage vs current
plt.scatter(current, voltage)
plt.xlabel('Current (A)')
plt.ylabel("Voltage (V)")
plt.title("Voltage and current in a resistor")

#add error bars
plt.errorbar(current, voltage, yerr=voltage_unc, fmt='None', capsize=8)

plt.show()

# %% [markdown]
# #### don't forget to explain!

# %% [markdown]
# ### Write a script 3 (25 pts)
# #### Creating a plot with axes labels and units!
#
# Make an interactive plot of
# $$ x = 3e^{(\frac{\pi t^{3/2}}{8})}$$
# from
# $$t=0 \;\;\mathrm{to}\;\; t=5\;\mathrm{sec}$$
# where $x$ is measured in meters. Once again, google is your friend, and the Matplotlib site has many examples.Make sure that you have a sufficient number of points in your $t$ array so that the plot looks smooth; i.e. 20 points is far to few points!
# Make sure that you include axes labels with units.

# %%
#%matplotlib notebook 
# %matplotlib ipympl 
#%matplotlib inline

# create time array 
t = np.linspace(0,5,1000)
# use equation to calculation x array 
x = 3*np.exp(np.pi*t**(3/2)/8)

# plot the data
plt.scatter(t,x)
plt.xlabel("time (s)")
plt.ylabel("x (m)")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### don't forget to explain!
