# %% [markdown]
# # Class 13: Solving Nonlinear Equations Pt. 1
#
# Ch. 6, sections 3.1-3.4: Relaxation Method & Binary Search
#
# - Complete the activities as instructed by the professor

# %% [markdown]
# #### Import any packages we need below (update as we go):

# %%
import numpy as np
import math

# %% [markdown]
# ### The Relaxation Method
# #### Single Variable
#
# Outline:
# 1) Guess an initial value for the unknown variable, plug into the right hand side.
#
# 2) Repeat the process by taking this value and plugging back into RHS.
#
# 3) Continue until eventually converges to a fixed point of the equation – until “relaxes” into solution.
#
# 4) Continue until eventually converges to a fixed point of the equation – until “relaxes” into solution. If the process converges, gives you a solution to the equation since feed one value into RHS and get same out on LHS.
#
#
#
#
#
#
# #### Let's apply for the function:
#
# $$ y = \cos y +\frac{1}{3} $$

# %%
def f(y):
    return math.cos(y) + (1/3)

N = 50 # Number of interations

y = 1/3
print(y)

for k in range(N):
    y = f(y)
    print(y)
# Out:
# 0.3333333333333333
# 1.278290279648071
# 0.6216860623263328
# 1.1462309721165007
# 0.745258097419037
# 1.0682462284584842
# 0.8149952324914838
# 1.0192051962202648
# 0.8573763778817238
# 0.9877568462360671
# 0.8838971467314116
# 0.9674759641915682
# 0.9007131026693727
# 0.9543845510919737
# 0.9114443811718265
# 0.9459380986725299
# 0.9183156286300245
# 0.9404927185457554
# 0.922723387935807
# 0.9369845141667075
# 0.9255538531703107
# 0.9347255147891045
# 0.9273725878824932
# 0.9332714356328606
# 0.9285416731659097
# 0.9323357033650201
# 0.9292933401857202
# 0.9317336389024313
# 0.9297766984063442
# 0.9313463037243719
# 0.9300875502376669
# 0.9310971313131664
# 0.930287473653183
# 0.9309368463081062
# 0.9304160586946197
# 0.9308337429400921
# 0.9304987629463675
# 0.9307674229536989
# 0.9305519580946753
# 0.9307247639605021
# 0.9305861734123759
# 0.9306973246437071
# 0.9306081809744027
# 0.9306796750893009
# 0.9306223364705171
# 0.9306683225567798
# 0.9306314414592807
# 0.9306610204053329
# 0.9306372979098048
# 0.930656323537709
# 0.9306410648612511

# %% [markdown]
# How about: $y = \cos y + \frac{1}{y^2}$

# %%
def f1(y):
    return math.exp(1-y**2)

N = 100 # Number of interations

y = .5
print(y)

for k in range(N):
    y = f1(y)
    print(y)
# Out:
# 0.5
# 2.117000016612675
# 0.030755419069985038
# 2.715711832754083
# 0.0017034651847384463
# 2.71827394057758
# 0.001679913095081425
# 2.7182741571849562
# 0.0016799111168229455
# 2.7182741572030236
# 0.0016799111166579386
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221
# 2.7182741572030253
# 0.0016799111166579221

# %% [markdown]
# ### Relaxation Method - Multi-variable
#
# #### Glycolosis (book problem 6.13)
#
#
# The biochemical process of glyocolysis, the breakdown of glucose in the body to release energy, can be modeled by the equations
# $$ \frac{dx}{dt} = -x + ay + x^2 y, \qquad
# \frac{dy}{dt} = b - ay - x^2 y.
# $$
# Here $x$ and $y$ represent concentrations of two chemicals, ADP and F6P, and $a$ and $b$ are positive constants.  One of the important features of nonlinear linear equations like these is their stationary points, meaning values of $x$ and $y$ at which the derivatives of both variables become zero simultaneously, so that the variables stop changing and become constant in time.  Setting the derivatives to zero above, the stationary points of our glycolysis equations are solutions of
# $$
# -x + ay + x^2 y = 0, \qquad b - ay - x^2 y = 0.
# $$
#
# *(b)* Show that the equations can be rearranged to read
# $$x = y(a+x^2),\qquad y = {b\over a+x^2}$$
# Write a program to solve these for the stationary point using the relaxation method with $a=1$ and $b=2$.  You should find that the method fails to converge to a solution in this case.
#
# *(c)* Find a different way to rearrange the equations such that when you
#   apply the relaxation method again it now converges to a fixed point and
#   gives a solution.  Verify that the solution you get agrees with part~(a).

# %%
def f(x, y):
    return y*(a+x**2)

def g(x,y):
    return b/(a+x**2)

#Define constatns and startig parts
a = 1.
b = 2.
N = 50
x = 0
y = 0

#Apply releaxation method
for k in range(N):
    x, y = f(x, y), g(x,y)
    print(x, y)
# Out:
# 0.0 2.0
# 2.0 2.0
# 10.0 0.4
# 40.400000000000006 0.019801980198019802
# 32.33980198019803 0.0012246197555658964
# 1.2820088565950922 0.0019104700396819156
# 0.005050416784875509 0.756559357795263
# 0.7565786551351739 1.9999489878817491
# 3.1447423107830907 1.2719318724615818
# 13.850580275660693 0.1836647775251292
# 35.417653786926245 0.010371368957981375
# 13.020322375433697 0.0015931047878737202
# 0.27167023940284046 0.011728224566485684
# 0.012593822884716614 1.862536050228023
# 1.862831456593908 1.999682841553014
# 8.938864328362877 0.44741317646091827
# 36.19720041725602 0.02472087185215718
# 32.41492970720614 0.001525276906379439
# 1.6041759236834312 0.0019016329616482113
# 0.006795257941976698 0.559694121366948
# 0.5597199655399187 1.9999076532031665
# 2.6264516018519726 1.5228970157249306
# 12.028218334347882 0.25322071372384936
# 36.88869632545642 0.013728905542758634
# 18.69569292929159 0.0014686704145903883
# 0.5148114749799199 0.0057056630862692935
# 0.007217839851058589 1.5809891058839396
# 1.5810714710087412 1.999895811003725
# 6.999209353581155 0.5714633496369059
# 28.566842282766988 0.04000885670038809
# 32.689815615618826 0.002447787235684028
# 2.618212084290489 0.0018698158566840132
# 0.01468746809716388 0.25461377608644076
# 0.254668701807926 1.9995686496134364
# 2.129252969250132 1.8781879640328814
# 10.393362932850653 0.3614206443414824
# 39.40279897695265 0.01834492237736123
# 28.500314912593623 0.0012873487492066297
# 1.0469594783529679 0.00245921408769675
# 0.005154818037552187 0.9541419579824898
# 0.9541673115847648 1.9999468571141201
# 3.8207689909508717 1.0468818511932043
# 16.329551721615772 0.1282193006936528
# 34.318441971654245 0.007472326441833064
# 8.808045587444255 0.0016967047610391027
# 0.13332988864890058 0.025451228951477764
# 0.025903671865196567 1.965067275707218
# 1.966385836273868 1.9986588994465617
# 9.72681981599846 0.4109583475904861
# 39.29214832470747 0.020918090005889015

# %% [markdown]
# Alternatives:

# %%
def f(x, y):
    return math.sqrt(b/y - a)

def g(x,y):
    return x/(a+x**2)

#Define constatns and startig parts
a = 1.
b = 2.
N = 50
x = 1
y = 1

#Apply releaxation method
for k in range(N):
    x, y = f(x, y), g(x,y)
    print(x, y)
# Out:
# 1.0 0.5
# 1.7320508075688772 0.5
# 1.7320508075688772 0.43301270189221935
# 1.902314945932194 0.43301270189221935
# 1.902314945932194 0.4118632672940252
# 1.9636650714924069 0.4118632672940252
# 1.9636650714924069 0.40438075610800917
# 1.9864122863201303 0.40438075610800917
# 1.9864122863201303 0.40163345114218674
# 1.9949097477571613 0.40163345114218674
# 1.9949097477571613 0.400611243354449
# 1.9980918687165672 0.400611243354449
# 1.9980918687165672 0.4002290339314792
# 1.9992845505793713 0.4002290339314792
# 1.9992845505793713 0.40008586211625663
# 1.9997317204769791 0.40008586211625663
# 1.9997317204769791 0.40003219469412865
# 1.9998993971476058 0.40003219469412865
# 1.9998993971476058 0.40001207250421084
# 1.9999622742071335 0.40001207250421084
# 1.9999622742071335 0.4000045271179152
# 1.9999858528665935 0.4000045271179152
# 1.9999858528665935 0.400001697659211
# 1.9999946948304455 0.400001697659211
# 1.9999946948304455 0.4000006366207968
# 1.9999980105621868 0.4000006366207968
# 1.9999980105621868 0.40000023873260093
# 1.9999992539609281 0.40000023873260093
# 1.9999992539609281 0.40000008952469757
# 1.9999997202353632 0.40000008952469757
# 1.9999997202353632 0.4000000335717577
# 1.9999998950882634 0.4000000335717577
# 1.9999998950882634 0.4000000125894086
# 1.999999960658099 0.4000000125894086
# 1.999999960658099 0.4000000047210282
# 1.9999999852467871 0.4000000047210282
# 1.9999999852467871 0.4000000017703856
# 1.999999994467545 0.4000000017703856
# 1.999999994467545 0.4000000006638946
# 1.9999999979253296 0.4000000006638946
# 1.9999999979253296 0.40000000024896043
# 1.9999999992219986 0.40000000024896043
# 1.9999999992219986 0.4000000000933602
# 1.9999999997082494 0.4000000000933602
# 1.9999999997082494 0.4000000000350101
# 1.9999999998905935 0.4000000000350101
# 1.9999999998905935 0.4000000000131288
# 1.9999999999589726 0.4000000000131288
# 1.9999999999589726 0.4000000000049233
# 1.9999999999846148 0.4000000000049233

# %% [markdown]
# ### Binary Search
#
# Outline:
# 1) Given an initial pair of points $x_1, x_2$ check that $f(x_1)$ and $f(x_2)$ have opposite signs. Also choose a target accuracy for the answer you want.
#
# 2) Calculate the midpoint $x' = \frac{1}{2}(x_1+x_2)$ and evaluate $f(x')$
#
# 3) If $f(x')$ has the same sign as $f(x_1)$ then set $x_1 = x'$. Otherwise set $x_2 = x'$.
#
# 4) If $|{x_1-x_2}|$ is greater than the target accuracy, repeat from step 2. Otherwise, calculate $\frac{1}{2}(x_1+x_2)$ once more and this is the final estimate of the position of the root.
#
#
# #### Let's apply for the function:
#
# $$ f(x) = e^{x-\sqrt{x}}-x$$

# %%
# Define function
def f(x):
    return math.exp(x-math.sqrt(x)) - x

def binary_solve(x1, x2, f, accuracy):
    f1 = f(x1)
    nascar = f(x2)

    if f1*nascar < 0:
        while abs(x2-x1) > accuracy:
            xp = 0.5*(x1+x2)
            fp = f(xp)
            if fp*f1 >0:
                x1, f1 = xp, fp
            else:
                x2, nascar = xp, fp
        result = .5*(x1+x2)
    else: 
        result = -999.99
    return result

#Initial guesses and accuracy
x1 = 1.5
x2 = 5.

print(binary_solve(x1,x2,f,1e-15))
# Out:
# 2.490909316945985
