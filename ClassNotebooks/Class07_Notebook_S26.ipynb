# %% [markdown]
# # Class 07: Graphing in Python 3
#
# 3D graphics & Animations
#
# - Complete the activities as instructed by the professor

# %% [markdown]
# #### Import any packages we need below (update as we go):

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="vpython")

from vpython import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ### 3D graphics

# %% [markdown]
# #### Let's create a scene that has a sphere

# %% [markdown]
# #### Now make another sphere that is green!

# %%
scene = canvas(width=100, height=100, color=color.blue)
box(pos=vector(10, 10,0))
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# #### We can create a collection of spheres

# %%
scene1 = canvas().
L = 5
R = 0.3
for i in range(-L, L+1):
    for j in range(-L, L+1):
        for k in range(-L, L+1):
            sphere(pos=vector(i, j, k), radius=R, color=color.blue)
# Out:
#   Cell In[13], line 1
#     scene1 = canvas().
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### You can also store 3D shapes in an array

# %%
s = np.empty(10, sphere).
scene2 = canvas(range=10)
for x in np.linspace(-9,9,10):
    n=int(x)
    s[n] = sphere(pos=vector(n,0,0))
# Out:
#   Cell In[14], line 1
#     s = np.empty(10, sphere).
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Let's examine other shapes:
# - spheres
# - arrows
# - cones
# - springs

# %%
arroe = canvas(width = 500, height = 500, background = color.blue)
arrow = helix(pos=vector(0.3,1,1.5), axis = vector(0,1,5), color=color.yellow)
circle = sphere(pos=vector(-1,1,1))
circle = sphere(pos=vector(2,1,1))
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ##  Vectors & Rate
#
# #### Create an object & move it
# - Create a sphere and give it a specific location
# - Change the position
#
# What do you notice?

# %%
blue = canvas(width=500, height=500, range=2.5, autoscale=False)
xpos = -2
s = sphere(pos = vector(xpos,0,0), radius = 0.5)

for i in range(50):
    rate(20)
    xpos=xpos+0.1
    s.pos=vector(xpos,0,0)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# #### Using rate()
#
#  - Do the same as above, but use the rate function in between the creation and position
#  - What happens as you change the value in rate()?

# %%
total distance
stepsize
total_time
nsteps = int(totaldistance/stepsize)
tiem between = int(nsteps/total time

# %% [markdown]
# #### Looping through position change
# - Create a loop to change the position of the sphere 50 times

# %% [markdown]
# #### Autoscale and range
# - Turn off autoscale and adjust the range to make it stay in the scene

# %% [markdown]
# #### Determining rate quantitatively

# %% [markdown]
# #### Example: A Moving Sphere
#
# A program to move a sphere around on the screen in a uniform circle

# %%
seen = canvas(width = 800, height = 500)

xpos = 1
ypos = 0
r = 3

s = sphere(pos = vector(xpos,ypos,0), radius=0.1, color=color.orange)

for theta in np.arange(0, 10*np.pi, 0.1):
    rate(30)
    xpos = 1.0*np.cos(theta)
    ypos = 1.0*np.sin(theta)

    s.pos = vector(xpos, ypos, 0)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# How could I make the sphere get larger? how could I make it rotate?
