# %% [markdown]
# # Class 07: Graphing in Python 3
#
# 3D graphics & Animations
#
# - Complete the activities as instructed by the professor

# %% [markdown]
# #### Import any packages we need below (update as we go):

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="vpython")

from vpython import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3D graphics

# %% [markdown]
# #### Let's create a scene that has a sphere

# %%
scene = canvas(width=600, height=400, center=vector(5,0,0), background=color.cyan)
sphere(radius=0.5, pos=vector(1,0,0), color=color.green)
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 2
#       1 scene = canvas(width=600, height=400, center=vector(5,0,0), background=color.cyan)
# ----> 2 sphere(radius=0.5, pos=vector(1,0,0), color=color.green)
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\vpython.py:1189, in sphere.__init__(self, **args)
#    1187 args['_default_size'] = vector(2,2,2)
#    1188 args['_objName'] = "sphere"
# -> 1189 super(sphere, self).setup(args)
#    1190 self._sizing = False
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\vpython.py:612, in standardAttributes.setup(self, args)
#     611 def setup(self, args):
# --> 612     super(standardAttributes, self).__init__()
#     613     self._constructing = True  ## calls to setters are from constructor
#     615     objName = self._objName = args['_objName']  ## identifies object type
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\vpython.py:265, in baseObj.__init__(self, **kwargs)
#     262 if not (baseObj._view_constructed or
#     263         baseObj._canvas_constructing):
#     264     if _isnotebook:
# --> 265         from .with_notebook import _
#     266     else:
#     267         from .no_notebook import _
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\with_notebook.py:6
#       3 from threading import Thread
#       5 from jupyter_core.paths import jupyter_data_dir
# ----> 6 import notebook
#       7 import IPython
#       8 from IPython.display import display, Javascript
#
# ModuleNotFoundError: No module named 'notebook'

# %% [markdown]
# #### Now make another sphere that is green!

# %%
#see above

# %% [markdown]
# #### We can create a collection of spheres

# %%
scene1 = canvas()
L = 5
R = 0.3
for i in range(-L,L+1):
    for j in range(-L,L+1):
        for k in range(-L,L+1):
            sphere(pos=vector(i,j,0), radius=R, color=color.blue)
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 7
#       5 for j in range(-L,L+1):
#       6     for k in range(-L,L+1):
# ----> 7         sphere(pos=vector(i,j,0), radius=R, color=color.blue)
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\vpython.py:1189, in sphere.__init__(self, **args)
#    1187 args['_default_size'] = vector(2,2,2)
#    1188 args['_objName'] = "sphere"
# -> 1189 super(sphere, self).setup(args)
#    1190 self._sizing = False
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\vpython.py:612, in standardAttributes.setup(self, args)
#     611 def setup(self, args):
# --> 612     super(standardAttributes, self).__init__()
#     613     self._constructing = True  ## calls to setters are from constructor
#     615     objName = self._objName = args['_objName']  ## identifies object type
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\vpython.py:265, in baseObj.__init__(self, **kwargs)
#     262 if not (baseObj._view_constructed or
#     263         baseObj._canvas_constructing):
#     264     if _isnotebook:
# --> 265         from .with_notebook import _
#     266     else:
#     267         from .no_notebook import _
#
# File c:\Users\benma\miniconda3\envs\ldvpythenv\Lib\site-packages\vpython\with_notebook.py:6
#       3 from threading import Thread
#       5 from jupyter_core.paths import jupyter_data_dir
# ----> 6 import notebook
#       7 import IPython
#       8 from IPython.display import display, Javascript
#
# ModuleNotFoundError: No module named 'notebook'

# %% [markdown]
# #### You can also store 3D shapes in an array

# %%
s = np.empty(10,sphere)
scene2 = canvas(range=10)
for x in np.linspace(-9,9,10):
    n = int(x)
    s[n] = sphere(pos=vector(n,0,0))

# %% [markdown]
# #### Let's examine other shapes:
# - spheres
# - arrows
# - cones
# - springs

# %% [markdown]
# ##  Vectors & Rate
#
# #### Create an object & move it
# - Create a sphere and give it a specific location
# - Change the position
#
# What do you notice?

# %% [markdown]
# #### Using rate()
#
#  - Do the same as above, but use the rate function in between the creation and position
#  - What happens as you change the value in rate()?

# %% [markdown]
# #### Looping through position change
# - Create a loop to change the position of the sphere 50 times

# %% [markdown]
# #### Autoscale and range
# - Turn off autoscale and adjust the range to make it stay in the scene

# %% [markdown]
# #### Determining rate quantitatively

# %% [markdown]
# #### Example: A Moving Sphere
#
# A program to move a sphere around on the screen in a uniform circle

# %% [markdown]
# How could I make the sphere get larger? how could I make it rotate?
