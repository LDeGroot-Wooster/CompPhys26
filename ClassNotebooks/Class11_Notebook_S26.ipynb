# %% [markdown]
# # Class 11: Derivatives
#
# Ch. 5, sections 10 - 12: Derivatives, Second derivatives, & Interpolation
#
# - Complete the activities as instructed by the professor

# %% [markdown]
# #### Import any packages we need below (update as we go):

# %%
import numpy as np
import math

# %% [markdown]
# ### Forward, Backward, and Central difference
#
# Evaluate the derivative of $f(x) = e^{\sin(2x)}$ at $x = 0.5$

# %% [markdown]
# If you took the derivative by hand, what would it be?

# %%
def fprime(x):
    return 2*np.cos(2*x)*np.exp(np.sin(2*x))

# define variables
x = 0.5
true_val = fprime(x)
print(true_val)
# Out:
# 2.506761534986894

# %% [markdown]
# Now apply forward/backward difference

# %%
def f(x):
    return np.exp(np.sin(2*x))

# apply forward difference
def calc_fd(f,x,h):
    fd = (f(x+h)-f(x))/h
    return fd

# define variables and call
x = 0.5
h_fd = [10**(-i) for i in range(1,12)]

# define an array of fd values
fd_array = np.zeros(len(h_fd))

for j in range(len(fd_array)):
    fd_array[j] = calc_fd(f,x,h_fd[j])

fd_error = np.abs(fd_array - true_val)

print("the true value is ", true_val)
print(" h      forward diff        error")
rowf = "{0:1.0e} {1:1.16f} {2:1.16f}"

for i in range(len(h_fd)):
    print(rowf.format(h_fd[i], fd_array[i], fd_error[i]))
# Out:
# the true value is  2.506761534986894
#  h      forward diff        error
# 1e-01 2.1990570766492690 0.3077044583376249
# 1e-02 2.4807256192968197 0.0260359156900742
# 1e-03 2.5042064928371133 0.0025550421497806
# 1e-04 2.5065065168927703 0.0002550180941236
# 1e-05 2.5067360380326420 0.0000254969542519
# 1e-06 2.5067589857208361 0.0000025492660578
# 1e-07 2.5067612785534266 0.0000002564334673
# 1e-08 2.5067615538887367 0.0000000189018428
# 1e-09 2.5067619091601046 0.0000003741732106
# 1e-10 2.5067636855169440 0.0000021505300500
# 1e-11 2.5067947717616335 0.0000332367747395

# %%
# apply backward difference
def calc_bd(f,x,h): # only thing that changes
    bd = (f(x)-f(x-h))/h
    return bd

####################################

bd_array = np.zeros(len(h_fd))

for j in range(len(bd_array)):
    bd_array[j] = calc_bd(f,x,h_fd[j])

bd_error = np.abs(bd_array - true_val)

print("the true value is ", true_val)
print(" h      backward diff        error")
rowf = "{0:1.0e} {1:1.16f} {2:1.16f}"

for i in range(len(h_fd)):
    print(rowf.format(h_fd[i], bd_array[i], bd_error[i]))
# Out:
# the true value is  2.506761534986894
#  h      backward diff        error
# 1e-01 2.7076817455157842 0.2009202105288903
# 1e-02 2.5317171676925376 0.0249556327056437
# 1e-03 2.5093057730525281 0.0025442380656342
# 1e-04 2.5070164450369248 0.0002549100500309
# 1e-05 2.5067870308426166 0.0000254958557226
# 1e-06 2.5067640843090544 0.0000025493221605
# 1e-07 2.5067617892560179 0.0000002542691240
# 1e-08 2.5067615538887367 0.0000000189018428
# 1e-09 2.5067614650708947 0.0000000699159992
# 1e-10 2.5067592446248455 0.0000022903620485
# 1e-11 2.5067503628406484 0.0000111721462455

# %% [markdown]
# Now apply central difference

# %%
# apply central difference
def calc_cd(f,x,h): # only thing that changes
    cd = (f(x+h/2)-f(x-h/2))/h
    return cd

####################################

cd_array = np.zeros(len(h_fd))

for j in range(len(cd_array)):
    cd_array[j] = calc_cd(f,x,h_fd[j])

cd_error = np.abs(cd_array - true_val)

print("the true value is ", true_val)
print(" h      central diff        error")
rowf = "{0:1.0e} {1:1.16f} {2:1.16f}"

for i in range(len(h_fd)):
    print(rowf.format(h_fd[i], cd_array[i], cd_error[i]))
# Out:
# the true value is  2.506761534986894
#  h      central diff        error
# 1e-01 2.4932959255171205 0.0134656094697734
# 1e-02 2.5066264877375843 0.0001350472493096
# 1e-03 2.5067601844748211 0.0000013505120728
# 1e-04 2.5067615214791061 0.0000000135077878
# 1e-05 2.5067615348373096 0.0000000001495843
# 1e-06 2.5067615352369899 0.0000000002500959
# 1e-07 2.5067615361251683 0.0000000011382744
# 1e-08 2.5067615538887367 0.0000000189018428
# 1e-09 2.5067614650708947 0.0000000699159992
# 1e-10 2.5067636855169440 0.0000021505300500
# 1e-11 2.5067503628406484 0.0000111721462455

# %% [markdown]
# How do they compare?

# %%
# could print side by side
# could take differences
# could print errors side by side

# %% [markdown]
# ### Second derivatives
#
# Let's take the second derivative use central difference of the same function $f(x) = e^{\sin(2x)}$ at $x = 0.5$ & compare with the true value

# %% [markdown]
# $$ \frac{d^2}{dx^2}e^{\sin(2x)} = 2 e^{\sin(2x)}(-2\sin(2x)+\cos(4x)+1)  $$

# %%
def fdoubleprime(x):
    return 2*np.exp(np.sin(2*x))*(-2*np.sin(2*x) + np.cos(4*x) + 1)

def second_deriv(f,x,h):
    second_d = (f(x+h) -2*f(x)+f(x-h))/h**2
    return second_d

# variables and call functions
x = 0.5
true_val_doub = fdoubleprime(x)

secondderiv_array = np.zeros(len(h_fd))

for j in range(len(secondderiv_array)):
    secondderiv_array[j] = second_deriv(f,x,h_fd[j])

secondderiv_error = np.abs(secondderiv_array - true_val_doub)

print("the true value is ", true_val_doub)
print(" h      second diff        error")
rowf = "{0:1.0e} {1:1.16f} {2:1.16f}"

for i in range(len(h_fd)):
    print(rowf.format(h_fd[i], secondderiv_array[i], secondderiv_error[i]))
# Out:
# the true value is  -5.099281481682785
#  h      second diff        error
# 1e-01 -5.0862466886651516 0.0130347930176331
# 1e-02 -5.0991548395717956 0.0001266421109891
# 1e-03 -5.0992802154148364 0.0000012662679483
# 1e-04 -5.0992814415451448 0.0000000401376399
# 1e-05 -5.0992809974559341 0.0000004842268506
# 1e-06 -5.0985882182885689 0.0006932633942158
# 1e-07 -5.1070259132757210 0.0077444315929363
# 1e-08 0.0000000000000000 5.0992814816827847
# 1e-09 444.0892098500625593 449.1884913317453538
# 1e-10 44408.9209850062543410 44414.0202664879398071
# 1e-11 4440892.0985006261616945 4440897.1977821076288819

# %% [markdown]
# ### Automatic Differentiation - book example
#
# Store value/derivative pairs as two-element lists in Python of the form [value, derivative]
#
# Define some functions to perform basic mathematics operations on these inputted lists.
#
# Apply this to overall figure out the value of the function $f(x) = 3x^2 +e^x$ and its derivative at $t = 1/2$
#
# To do this, perform the following sequence of operations:
#
# $$ u_1 = x^2$$
# $$ u_2 = 3u_1$$
# $$ u_3 = e^x$$
#
# and finally
#
# $$ f(x) = u_2 + u_3$$
#
# Each each mathematical operation will be performed using the generalized operations listed above and the end result will be a pair $[f,f']$, representing the value of $f$ and its derivative.
#
# Final bit of info: to calculate the derivative $f'(t)$ at any value of $t$, need an input list to evaluate our function $f(𝑥)$. Use $[t,1]$ since for whatever value of $t$ we are interested in, by definition, this is the correct value/derivative pair for the independent variable $t$, because $dt/dt = 1$ always. So if we use this pair as the argument of our function, we will get out a pair representing the value of the function $f(t)$ and its derivative $f'(t)$, at the chosen value of $t$.

# %%
# a power, mult, exp, and add

def power(x,c):
    vx,dx = x
    return [vx**c, c*vx**(c-1)*dx]

def mult(x,c):
    vx,dx= x
    return [c*vx, c*dx]

def exponential(x):
    vx,dx = x
    return [math.exp(vx), math.exp(vx)*dx]

def add(x,y):
    vx,dx = x
    vy, dy = y
    return((vx+vy, dx+dy))

def f_ad(x):
    u1 = power(x,2)
    u2 = mult(u1,3)
    u3 = exponential(x)
    u4 = add(u2, u3)
    return u4

print(f_ad([0.5,1]))
# Out:
# (2.398721270700128, 4.648721270700128)

# %% [markdown]
# The actual value of the function and the derivative at $f(t)$ at $t = 1/2$ is
# $$f (t) = 3t^2 + e^t = \frac{3}{4} + e^{1/2} = 2.3987 ...$$
# $$ f'(t) = 6t + e^t = 3 + e^{1/2} = 4.6487 ...$$
#
# Look how exact we are!
