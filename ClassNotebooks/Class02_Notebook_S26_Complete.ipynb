# %% [markdown]
# # Class 02: Introduction & Basics of Python Programming
#
# Intro to Jupyter, Variables, functions, If and While statements
#
# - Complete the activities as instructed by the professor

# %% [markdown]
# ### First Codes
#
# - Add a code cell below this one and complete the "Hello World" activity

# %%
text = 'hello world!'
print(text)
# Out:
# hello world!

# %% [markdown]
# ### Add a markdown cell below this one and write a comment and/or type an equation.

# %% [markdown]
# I have defined my variable $x = 2$.
#
# $$ v = \lambda \nu $$

# %% [markdown]
# ### Variables & Calculations
#
# - Find out what happens when you run the cell below

# %%
x=5
X=7
print(x, X)
# Out:
# 5 7

# %% [markdown]
# - Define two variables: one that is a number and one that is a string
# - Check the type of each variable
# - print a sentence using the two variables

# %%
animal = "cheetahs"
number = 2
print(type(animal))
print(type(number))
print("I have ", number, " wonderful ", animal, ".", sep="")
# Out:
# <class 'str'>
# <class 'int'>
# I have 2 wonderful cheetahs.

# %% [markdown]
# - Define a variable that asks a user for their favorite color

# %%
fav_color = input("tell me your favorite color: ")

# %% [markdown]
# - Define a float variable, create another variable that is the float multiplied by itself, and create a third variable that is the variable cubed

# %%
aa = 3.5
bb = aa*aa
print(bb)
bb = aa**2
print(bb)
cc = aa**3
print(cc)
print(type(aa))
# Out:
# 12.25
# 12.25
# 42.875
# <class 'float'>

# %% [markdown]
# #### Example 2.1 - A ball dropped from a tower
#
# A ball is dropped from a tower of height $h$. It has an initial velocity of zero and accelerates downwards under gravity.
#
# Write a program that asks the user to enter the height in meters of the tower and the time interval $t$ in seconds, then prints on the screen the height of the ball above the ground at time $t$ after it is dropped, ignoring air resistance.
#
# Hint: 1D motion can be described by $ y = y_0 +v_{0y}t + \frac{1}{2}a_yt^2$

# %%
height = float(input("give a height of tower in meters: ")) # starting height 
timeelapsed = float(input("give time elapsed in seconds: ")) # total elapsed time 
ay = -9.81
y = height + ay*timeelapsed**2/2
print(y)
# Out:
# -22.500000000000014

# %% [markdown]
# ### Packages, Modules, & functions
#
# - import the math packages and calculate the $\log(2\pi)$
# - Which type of log is this?

# %%
import math
x = math.log(2*math.pi)
print(x)

y = math.log10(2*math.pi)
print(y)

print(math.pi)
# Out:
# 1.8378770664093453
# 0.798179868358115
# 3.141592653589793

# %% [markdown]
# #### Example 2.2 - Converting polar coordinates
#
# Suppose the position of a point in two-dimensional space is given to us in polar coordinates $r, \theta$ and we want to convert it to Cartesian coordinates $x, y$. How do we write a program to do this? The appropriate steps are:
# 1) Get the user to enter the values of $r$ and $\theta$.
#
# 2) Convert those values to Cartesian coordinates using the standard forumlas:
#
# $$ x = r \cos \theta \hspace{1in} y = r \sin \theta $$
#
# 3) Print out the results
#
# **Make sure your code is well commented!**

# %%
# ask user for r and theta 
r = float(input("Give me a value for r (in meters): "))
theta = float(input("Give me a value for theta (in degrees): "))

# convert angle to radians
#theta_rad = math.radians(theta)

# convert to x and y
x = r*math.cos(math.radians(theta))
y = r*math.sin(math.radians(theta))

print(x,y)
# Out:
# 7.0710678118654755 7.071067811865475

# %% [markdown]
# ### Controlling program flow
#
# if, while, break, and continue statements

# %% [markdown]
# - Write a simple if statement

# %%
var = float(input("Give me a number: "))

if var > 0:
    print("your number is positive")
# Out:
# your number is positive

# %% [markdown]
# Below is a code using if, elif, and else statements.
# - Run the code and do your best to see how it works.
# - In the cell below the sample code, make the code more efficient

# %%
# if, else, and elif statements 
import random 

n = int(input("Choose a number between 1 and 100: "))
if n>100:
    print("you have chosen a number outside of the boundaries. Assigning number now.")
    n = random.randint(1, 101)
    print("your number is: ", n)
elif n < 1:
    print("you have chosen a number outside of the boundaries. Assigning number now.")
    n = random.randint(1, 101)
    print("your number is: ", n)
else: 
    print("your number is: ", n)
# Out:
# your number is:  3

# %%
# more efficient version of the if, elif, else statement code 

n = int(input("Choose a number between 1 and 100: "))
if n>100 or n <1:
    import random 
    print("you have chosen a number outside of the boundaries. Assigning number now.")
    n = random.randint(1, 101)
    print("your number is: ", n)
else: 
    print("your number is: ", n)
# Out:
# your number is:  50

# %% [markdown]
# - Write a simple while statement

# %%
x = -10

while x < 0:
    print("x is less than 0 still!")
    x = x + 1
# Out:
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!
# x is less than 0 still!

# %% [markdown]
# - Choose various x values and run the code below to see how break statements are used

# %%
x = -105

while x<0:
    print("x is less than 0")
    x = x+1
    print(x)
    if x == -100:
        break    
        
print("x is now ", x)
# Out:
# x is less than 0
# -104
# x is less than 0
# -103
# x is less than 0
# -102
# x is less than 0
# -101
# x is less than 0
# -100
# x is now  -100
