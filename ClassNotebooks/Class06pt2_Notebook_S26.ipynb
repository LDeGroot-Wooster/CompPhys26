# %% [markdown]
# # Class 06: Graphing in Python 2 part 2
#
# 3D graphics
#
# - Complete the activities as instructed by the professor

# %% [markdown]
# #### Import any packages we need below (update as we go):

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="vpython")

from vpython import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import warnings
#       2 warnings.filterwarnings("ignore", category=UserWarning, module="vpython")
# ----> 4 from vpython import *
#       5 import numpy as np
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'vpython'

# %% [markdown]
# ### 3D graphics

# %% [markdown]
# #### Let's create a scene that has a sphere

# %% [markdown]
# #### Now make another sphere that is green!

# %% [markdown]
# #### We can create a collection of spheres

# %% [markdown]
# #### You can also store 3D shapes in an array

# %% [markdown]
# #### Let's examine other shapes:
# - spheres
# - arrows
# - cones
# - springs
