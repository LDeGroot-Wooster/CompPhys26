# %% [markdown]
# #### Name:

# %% [markdown]
# # PHYS 230 Lab Assignment 4
#
# ### Monday, February 2, 2026: Chapter 3.1-3.2
# - Graphing in python - Matplotlib PyPlot
# - Scatter plots

# %% [markdown]
# #### Start by importing any packages you need below (feel free to update as you go):

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Catch the errors! (20 pts - 5 pts each)
#
# **Please read directions carefully**
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. edit the problem cell with the corrected code so it will run [do not add a new cell] <br>
#     b. below the cell, add a new markdown cell that describes what was wrong with the code<br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
#1 - create a list and plot it
x=[1,2,6,8]
plt.plot(x)

# %% [markdown]
# For #1, plot means nothing if it isn't run through matplotlib.pyplot, so I imported that package at the top of the notebook, ran that cell, added plt. in the #1 cell, and bob was my uncle.

# %%
#2 
# instructions: make a plot of potential energy (E) of a 5 kg object given a range of heights (h) using circle markers
h = np.linspace(1,10,20)
print(h)
m = 5
g = 9.8
E = m*g*h
plt.plot(h,E, 'o')
plt.xlabel('height (m)')
plt.ylabel('Potential energy (j)')
# Out:
# [ 1.          1.47368421  1.94736842  2.42105263  2.89473684  3.36842105
#   3.84210526  4.31578947  4.78947368  5.26315789  5.73684211  6.21052632
#   6.68421053  7.15789474  7.63157895  8.10526316  8.57894737  9.05263158
#   9.52631579 10.        ]
# Text(0, 0.5, 'Potential energy (j)')

# %% [markdown]
# I first changed `np.arange` to `np.linspace`, so that h would actually have a list of numbers. To get circle markers, I added `'o'` after `h, E` in the plot statement. M and G were also undefined, so I defined them as 5 and 9.8, respectively. I added labels on my axes, and bob was once again my uncle.

# %%
#3 plotting a graph of sin(theta) vs. theta with axis labels
theta = np.arange(0,360,1) * (np.pi / 180)
y = np.sin(theta)
plt.plot(theta,y, "o")
plt.xlabel('theta (degrees)')
plt.ylabel('sin(theta)')
# Out:
# Text(0, 0.5, 'sin(theta)')

# %% [markdown]
# Numpy does not use degrees in its trig functions, so I converted theta to radians by multiplying by `(np.pi / 180)`. `plt.xpoints()` is not a valid way to lable an axis, so I changed that to `plt.xlabel()` (the same goes for the y axis label). I also increased the number of degrees from 90 to 360 and decreased the distance between points.

# %%
#4 - making a scatter plot of the array a and list b
a = np.linspace(0,100,5)
b = [1,2,3,4,5]
plt.scatter(a,b)

# %% [markdown]
# `np,linspace` should be `np.linspace`, comma should be a period. Also, the length of arrays have to match to be plotted in a scatter plot, so i decreased the length of array a to 5, instead of typing out 45 more data points for b.

# %% [markdown]
# ## Short python snippets (10 pts - 5 pts each)
# Below each markdow cell, write a short python snippet to perform the indicated action; you will likely have to use google to find out how to perform some of these actions--this is deliberate on my part. Google and *stack overflow* are your friends.<br>
# Add a markdown cell to explain your thinking if this is needed.

# %% [markdown]
# 1. Create a list of 10 random integers between 0 and 20 and plot them. (You should look up how to make it random!)

# %%
import random
list = []
for num in range(10):
    list.append(random.randint(0,20))
print(list)
plt.plot(list)
# Out:
# [11, 17, 17, 11, 0, 11, 9, 8, 17, 19]

# %% [markdown]
# I made a for loop that will run 10 times, and each time it runs it used the random library and the command `random.randint(0,20)` to append a random number between 0 and 20 to the list. I print the list, and plot it.

# %% [markdown]
# 2. Make a scatter plot of two random independent arrays with 50 floating point values. Make all points larger & magenta.

# %%
x = [random.random() for _ in range(50)]
y = [random.random() for _ in range(50)]

plt.scatter(x, y, c="m", s=100)

# %% [markdown]
# I created the arrays using the random library and random command, which creates random floats between 0 and 1. I plotted these against each other and then used `c="m", s=100` to change the color and size.

# %% [markdown]
# ### Write a script 1 (27 pts)
# #### Plotting a wave
#
# Write a code to do the following:
# - Create an array "t" that consists of float points between 0 and 20.
#     - Make sure to use enough points so that the graph looks smooth
# - Assuming this is wave data following the equation $y(t) = A\sin(\omega t)$, calculate $y$ using $\omega = 0.5$.
#     - Ask the user for the value of $A$.
# - Make a plot of $y$ vs $t$, making all points cyan diamond markers
# - Add a second set of data to your plot using cosine instead
#     - You choose the color and marker style (must be different from sine)
# - Don't forget to add a title and label your axes
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
# create array with linspace
t = np.linspace(0,20,100)

# create an array for the equation y(t) = Asin(omega*t) based on the t array
A = float(input('A?'))
y = A * np.sin(0.5 * t)


# plot y vs t
plt.figure(1)
plt.plot(t, y, 'cD')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title("Plot of y(t) vs. t")

# create new function using sine, and plot it
plt.figure(2)
x = A * np.cos(0.5 * t)
plt.plot(t, x, 'y--')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.title("Plot of x(t) vs. t")
# Out:
# A? 5
# Text(0.5, 1.0, 'Plot of x(t) vs. t')

# %% [markdown]
# I create the array t using linspace, and then create the function y based off of that. I plot using plt.plot and within that I can change the color and marker style. Using plt.figure(), I can differentiate between the sin plot and cosine plot, and apply the right labels to each one.

# %% [markdown]
# ### Write a script 2 (22 pts)
# #### Importing data for a scatter plot
#
# Write a code to do the following:
# - Download the file "circuit.txt" from Moodle
#     - The first column is of voltage, the second column is of current, and the third column is the uncertainty in the voltage
# - Make a scatter plot of the data so that if you knew how to do a linear fit to the data the slope would be resistance.
# - Label the axes with units and title the graph "Voltage and current in a resistor"
# - Add error bars to the plot for the uncertainty in the voltage
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
# load in data, and assign V and I the respective lists from the .txt file
circuit_data = np.loadtxt('circuit.txt', float)
V = circuit_data[:,0]
I = circuit_data[:,1]

# plot V over I and label 
plt.scatter(I, V)
plt.xlabel('Current (amps)')
plt.ylabel('Voltage (volts)')
plt.title("Voltage and current in a resistor")

# create error values and plot on graph
volt_err = np.ones(len(V)) *15
plt.errorbar( I, V, yerr=volt_err, fmt='None', capsize=2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# After importing circuit.txt I assign the correct values of voltage and current to two variables. I plot and label those variables and then create error bars using the .errorbar function.

# %% [markdown]
# ### Write a script 3 (22 pts)
# #### Creating a plot with axes labels and units!
#
# Make an interactive plot of
# $$ x = 3e^{(\frac{\pi t^{3/2}}{8})}$$
# from
# $$t=0 \;\;\mathrm{to}\;\; t=5\;\mathrm{sec}$$
# where $x$ is measured in meters. Once again, google is your friend, and the Matplotlib site has many examples.Make sure that you have a sufficient number of points in your $t$ array so that the plot looks smooth; i.e. 20 points is far to few points!
# Make sure that you include axes labels with units.

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
# create an array for t first
t = np.linspace(0, 5, 500)

# create x based on t
x = 3 * np.e ** ((np.pi * t ** (3/2)) / 8)

plt.figure(1)
plt.scatter(x, t, c='g', s=3)
plt.xlabel('Distance (meters)')
plt.ylabel('Time (seconds)')
plt.title('Plot of Distance over Time')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
I created the array t and then created the array x based on t. I plotted this and everything goes well until I try to do the interactive  plot.
