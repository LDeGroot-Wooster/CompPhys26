# %% [markdown]
# #### Name: Mason Miller

# %% [markdown]
# # PHYS 230 Lab Assignment 4
#
# ### Monday, February 2, 2026: Chapter 3.1-3.2
# - Graphing in python - Matplotlib PyPlot
# - Scatter plots

# %% [markdown]
# #### Start by importing any packages you need below (feel free to update as you go):

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Catch the errors! (20 pts - 5 pts each)
#
# **Please read directions carefully**
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. edit the problem cell with the corrected code so it will run [do not add a new cell] <br>
#     b. below the cell, add a new markdown cell that describes what was wrong with the code<br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
#1 - create a list and plot it
x=[1,2,6,8]
plt.plot(x)

# %% [markdown]
# All I did here was import matplotlib and add plt. before plot(x). Without the matplotlib package, python has no ability to plot.

# %%
#2 
# instructions: make a plot of potential energy (E) of a 5 kg object given a range of heights (h) using circle markers
# constants
m = 5.0
g = 9.8

h = np.arange(1,10,0.5)
E = m*g*h
plt.plot(h,E)

# %% [markdown]
# Assuming we want 20 points in h, we need to adjust the argument of np.arange(). The last arguement is step size, not number of points (like np.linspace()). Well make the step size 0.5, so that there are 20 points between 1 and 10. We also need to define mass and g, and mg won't multiply, we need a * in between.

# %%
#3 plotting a graph of sin(theta) vs. theta with axis labels
theta = np.arange(0,90,0.1)
y = np.sin(theta)
plt.plot(theta,y)
plt.title('Points')
plt.xlabel('theta (degrees)')
plt.ylabel('sin(theta)')
# Out:
# Text(0, 0.5, 'sin(theta)')

# %% [markdown]
# Ill decrease the step size to increase the resolution of the plot. If "points" in the arguement of the plot statement is meant to be the title, ill pull that out and make a title statement. Xaxis and y axis need to be xlabel and ylabel.

# %%
#4 - making a scatter plot of the array a and list b
a = np.linspace(0,100,5)
b = [1,2,3,4,5]
plt.scatter(a,b)

# %% [markdown]
# np,linspace -> np.linspace. To plot a scatterplot, the list/arrays should be the same size. If I change the step number of points in a to 5, they are equal and can be plotted.

# %% [markdown]
# ## Short python snippets (10 pts - 5 pts each)
# Below each markdow cell, write a short python snippet to perform the indicated action; you will likely have to use google to find out how to perform some of these actions--this is deliberate on my part. Google and *stack overflow* are your friends.<br>
# Add a markdown cell to explain your thinking if this is needed.

# %% [markdown]
# 1. Create a list of 10 random integers between 0 and 20 and plot them. (You should look up how to make it random!)

# %%
# make empty list
vals = []

# fill it with random for loop
for num in range(20):
    rand = random.randint(1,10)
    vals.append(rand)

plt.plot(vals)

# %% [markdown]
# After completing the course and revisiting this lab, I didn't have to look up how to generate random integers, thanfully. Here, I made an empty list and fill it with a simplr for loop. At first, I named my list "random", and then had problems in the loop because I was calling the list when I was running random.randint() instead of the actual random library, so I changed the name to "vals".

# %% [markdown]
# 2. Make a scatter plot of two random independent arrays with 50 floating point values. Make all points larger & magenta.

# %%
# using numpy, create random floating arrays with dimensions 1x50
a = np.random.rand(1, 50)
b = np.random.rand(1, 50)

plt.scatter(a,b, color='m', s=102)

# %% [markdown]
# I looked up random arrays in python and found np.random.rand(), which I didnt know about. The argument is just (a, b) which makes an axb array of floats between 0 and 1. In plt.scatter, I changes the marker color and size.

# %% [markdown]
# ### Write a script 1 (27 pts)
# #### Plotting a wave
#
# Write a code to do the following:
# - Create an array "t" that consists of float points between 0 and 20.
#     - Make sure to use enough points so that the graph looks smooth
# - Assuming this is wave data following the equation $y(t) = A\sin(\omega t)$, calculate $y$ using $\omega = 0.5$.
#     - Ask the user for the value of $A$.
# - Make a plot of $y$ vs $t$, making all points cyan diamond markers
# - Add a second set of data to your plot using cosine instead
#     - You choose the color and marker style (must be different from sine)
# - Don't forget to add a title and label your axes
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
# create t array
t = np.linspace(0,20,100)

# prompt user for A
A = float(input("A=",))

# create the wave array
y = A*np.sin(0.5 * t)

# adding a second data set
y2 = np.cos(0.5 * t)

# plot
plt.plot(t, y, color='c', marker='D')
plt.plot(t, y2, color='g', marker='o')
plt.title('Plot of Asin(wt) and cos(wt)')
plt.ylabel('Amplitude')
plt.xlabel('t')
plt.show()
# Out:
# A= 3

# %% [markdown]
# I use linspace to make my time array. The user input needs to be a float, so I make sure that is the case. I picked cos(wt) as my other data set, which is arguably boring, cause Im a boring guy. I can plot the two sets on the same graph as long as my plt.plot() statements come before my plt.show() statement.

# %% [markdown]
# ### Write a script 2 (22 pts)
# #### Importing data for a scatter plot
#
# Write a code to do the following:
# - Download the file "circuit.txt" from Moodle
#     - The first column is of voltage, the second column is of current, and the third column is the uncertainty in the voltage
# - Make a scatter plot of the data so that if you knew how to do a linear fit to the data the slope would be resistance.
# - Label the axes with units and title the graph "Voltage and current in a resistor"
# - Add error bars to the plot for the uncertainty in the voltage
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
# read in the data
data = np.loadtxt("circuit.txt")

# assign the columns to variables
voltage = data[:, 0]
current = data[:, 1]
# uncertainty = data[:, 2]

# plot
# plt.errorbar(current, voltage, yerr=uncertianty)
# plt.title("Voltage and current in a resistor")
# plt.ylabel('Voltage')
# plt.xlabel('Current')
# plt.show()

# plot without uncertianty
plt.scatter(current, voltage)
plt.title("Voltage and current in a resistor")
plt.ylabel('Voltage')
plt.xlabel('Current')
plt.show()

# %% [markdown]
# I read in the data with np.loadtxt, and assign each column to a variable. I will forever have to look up indexing and how to assign rows and columns and everything. No matter how many times I do it, I cant remember the order of colons and commas and the like. I opened circuit.txt and found that there was no uncertianty column, so I was not able to do the error bar part, but I kept all of the lines that I'd need if there was a third column, commented them out, and just made a scatterplot. Voltage is on the y axis since V/I = R

# %% [markdown]
# ### Write a script 3 (22 pts)
# #### Creating a plot with axes labels and units!
#
# Make an interactive plot of
# $$ x = 3e^{(\frac{\pi t^{3/2}}{8})}$$
# from
# $$t=0 \;\;\mathrm{to}\;\; t=5\;\mathrm{sec}$$
# where $x$ is measured in meters. Once again, google is your friend, and the Matplotlib site has many examples.Make sure that you have a sufficient number of points in your $t$ array so that the plot looks smooth; i.e. 20 points is far to few points!
# Make sure that you include axes labels with units.

# %%
# import wigits from matplotlib
from matplotlib.widgets import Slider

# create arrays and the x data
t = np.linspace(0,5,500)

# define x as a function of t
def x(t):
    return 3* np.exp((np.pi*t*(1.5))/8)

# set an initial x point
t0 = 0.0
x0 = 3* np.exp((np.pi*t0*(1.5))/8)

# create figure and curve to be manipulated
fig, ax = plt.subplots()
curve, = ax.plot(t, x(t))

# label things
ax.set_xlabel('Time (s)')
ax.set_ylabel('x (m)')
ax.set_title('plot of x over t for a function of t')

# now we make a slider 
ax_slider = fig.add_axes([0.15, 0.1, 0.65, 0.03])
t_slider = Slider(
    ax=ax_slider,
    label='t (s)',
    valmin=0.0,
    valmax=5.0,
    valinit=t0,
)

# define a function that is called when the slider value changes
def update(val):
    line.set_ydata(f(t, amp_slider.val, freq_slider.val))
    fig.canvas.draw_idle()

# %% [markdown]
# I used the information from https://matplotlib.org/stable/gallery/widgets/slider_demo.html to try this excersize. You will notice that the slider does not do anything; I did my best to apply the info from the example to this problem. Its also possible that, since I am doing this lab 3 months late, I wasnt meant to use a slider at all and we were told to do something completley different. Nevertheless, I tried to implement a slider onto my plot. I tried to use code from the example on matplotlibs site, but I applied it very shoddily. A slider did show up though!
