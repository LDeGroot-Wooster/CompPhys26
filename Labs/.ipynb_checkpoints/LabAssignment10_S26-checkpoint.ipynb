# %% [markdown]
# #### Name:

# %% [markdown]
# # PHYS 230 Lab Assignment 10
#
# ### Wednesday, February 25, 2026: Chapter 5.10-5.12
# - Evaluating derivatives in python
# - Automatic Differentiation (& Interpolation)
#
# ***Don't forget to include comments in your code and a final markdown explanation at the end of each problem.***

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Derivatives with front, back, and central difference (25 pts)
#
# Let's evaluate the derivative of:
#
# $$ f(x) = \frac{1-\cos x}{x^2} $$
#
# I don't want to do this by hand, so let's do it computationally.
#
# *Note: don't forget to put brief comments in your code*

# %% [markdown]
# #### Step 1: Define the function `f(x)` that returns the function $f(x)$ from above.

# %%
def f(x):
    return (1-math.cos(x))/(x**2)

# %% [markdown]
# #### Step 2: Define functions that call on your function from step 1 to calculate the front, back, and central difference first derivatives of $f(x)$ at a specific location $x$.

# %%
def fd_diff(f, x, h):
    return (f(x+h)-f(x))/h
def bd_diff(f, x, h):
    return (f(x)-f(x-h))/h
def cd_diff(f, x, h):
    return (f(x+h/2)-f(x-h/2))/h

# %% [markdown]
# #### Step 3: Evaluate the derivative using the three different approximations using the appropriate value of $h$ for each method evaluated from $x = 0.004$ to $x = \frac{\pi}{2}$ - let's do 20 calculations.

# %%
x_arr = np.linspace(0.004, math.pi/2, 20)
fd = []
bd = []
cd = []
for x in x_arr:
    fd.append(fd_diff(f, x, 1e-8))
    bd.append(bd_diff(f, x, 1e-8))
    cd.append(cd_diff(f, x, 1e-5))
print((" forward            backward             central"))
rowf = "{0:1.16f} {1:1.16f} {2:1.16f}"
for i in range(len(x_arr)):
    print(rowf.format(fd[i], bd[i], cd[i]))
# Out:
#  forward            backward             central
# 0.0000415223411210 -0.0007212619390629 -0.0003336258658226
# -0.0072017447561024 -0.0072004124884728 -0.0072016567431721
# -0.0140503386703017 -0.0140503775281076 -0.0140504008483422
# -0.0208609296503681 -0.0208609574059437 -0.0208609633345347
# -0.0276148326427972 -0.0276148492961426 -0.0276148813205257
# -0.0342939232567119 -0.0342938732966758 -0.0342938977826446
# -0.0408799882833932 -0.0408800437945445 -0.0408800281237465
# -0.0473556360791605 -0.0473556360791605 -0.0473556252822416
# -0.0537034472447573 -0.0537034527958724 -0.0537034430259098
# -0.0599066962703176 -0.0599067018214328 -0.0599066982687191
# -0.0659491294907610 -0.0659491405929913 -0.0659491308729887
# -0.0718150594547495 -0.0718150594547495 -0.0718150615641733
# -0.0774894370891843 -0.0774894537425297 -0.0774894472366228
# -0.0829579238637024 -0.0829579349659326 -0.0829579337557895
# -0.0882069084440218 -0.0882069084440218 -0.0882069055962997
# -0.0932235344475174 -0.0932235344475174 -0.0932235327211206
# -0.0979958114655233 -0.0979958225677535 -0.0979958138802583
# -0.1025126150633326 -0.1025126150633326 -0.1025126167064627
# -0.1067637145357736 -0.1067637145357736 -0.1067637139973154
# -0.1107398062138998 -0.1107398173161300 -0.1107398163502360

# %% [markdown]
# #### Step 4: Determine the equation for the derivative (by hand and then type in below this cell as markdown). Computationally calculate the true value of the derivative at the range of values from step 3 and compare to your calculated values. Explain your results in a markdown cell.

# %% [markdown]
# $\frac{\mathrm{d}f}{\mathrm{d}x} = -2x^{-3} + 2x^{-3}\cos(x) + x^{-2}\sin(x)$

# %%
def fprime(x):
    return -2*x**(-3) + 2*math.cos(x)*x**(-3) + math.sin(x)*x**(-2)

x_arr = np.linspace(0.004, math.pi/2, 20)
ad = []
for x in x_arr:
    ad.append(float(fprime(x)))
print(ad)
# Out:
# [-0.0003333308827109249, -0.007201656745975171, -0.014050400860412537, -0.02086096336688259, -0.02761488129142986, -0.03429389774113867, -0.04088002813454161, -0.047355625281426006, -0.05370344303821306, -0.05990669827147066, -0.06594913086987031, -0.07181506155401818, -0.07748944724371964, -0.08295793375351512, -0.08820690559963773, -0.09322353271485684, -0.09799581388188705, -0.10251261671110795, -0.10676371400420082, -0.11073981636184083]

# %% [markdown]
# The central difference approximation is closer to the actual value for all points. The differences were less pronounced at values at the uppper end of the range computed.

# %% [markdown]
# #### Step 5: Evalute the derivative using the three approximations with a value of $h=10^{-6}$. Compare (computationally and in markdown) the values with each other and the true value.

# %%
x_arr = np.linspace(0.004, math.pi/2, 20)
fd = []
bd = []
cd = []
for x in x_arr:
    fd.append(fd_diff(f, x, 1e-6))
    bd.append(bd_diff(f, x, 1e-6))
    cd.append(cd_diff(f, x, 1e-6))
print((" forward            backward             central"))
rowf = "{0:1.16f} {1:1.16f} {2:1.16f}"
for i in range(len(x_arr)):
    print(rowf.format(fd[i], bd[i], cd[i]))
# Out:
#  forward            backward             central
# -0.0003299469031326 -0.0003359194034047 -0.0003329334585800
# -0.0072017040109174 -0.0072016125285401 -0.0072016508867456
# -0.0140504414769538 -0.0140503587098273 -0.0140504018419918
# -0.0208610037577550 -0.0208609231555634 -0.0208609627350143
# -0.0276149217937061 -0.0276148405253807 -0.0276148813260768
# -0.0342939379116558 -0.0342938575870200 -0.0342938978326046
# -0.0408800676643395 -0.0408799885609490 -0.0408800282514221
# -0.0473556642233142 -0.0473555863966801 -0.0473556254765306
# -0.0537034812175818 -0.0537034050562823 -0.0537034430814209
# -0.0599067354611904 -0.0599066611317589 -0.0599066983242302
# -0.0659491668497658 -0.0659490947962915 -0.0659491308785398
# -0.0718150965917097 -0.0718150265366369 -0.0718150615641733
# -0.0774894810540161 -0.0774894134969450 -0.0774894473032361
# -0.0829579661631996 -0.0829579012151527 -0.0829579337446873
# -0.0882069366991978 -0.0882068744156861 -0.0882069056684642
# -0.0932235623696265 -0.0932235030282058 -0.0932235327266717
# -0.0979958419966565 -0.0979957857638603 -0.0979958139080139
# -0.1025126433185086 -0.1025125901388257 -0.1025126166731560
# -0.1067637389606801 -0.1067636890561552 -0.1067637140916844
# -0.1107398395205905 -0.1107397931687792 -0.1107398163724405

# %% [markdown]
# When all the estimates share the same value of $h$, the differences between estimations is lower than when $h$ is different.

# %% [markdown]
# ## Second derivative (22 pts)
#
# Let's take the second derivative of the function from above.
#
# *Note: don't forget to put brief comments in your code*

# %% [markdown]
# #### Step 1: Define functions that call on your function from step 1 above to calculate the second derivative of $f(x)$ at a specific location $x$ using central difference.

# %%
def cdiff_2(f, x, h):
    return (cd_diff(f, x + h/2, h) - cd_diff(f, x - h/2, h)) / h

# %% [markdown]
# #### Step 2: Evalute the second derivative at $x = 0.004$ using a range of $h$ values from `1e-1` to `1e-12`.

# %%
h_arr = [10**(-i) for i in range(1, 12)]
cd = []
for h in h_arr:
    cd.append(cdiff_2(f, 0.004, h))
rowf = "{0:1.0e} {1:1.16f}"
for i in range(len(h_arr)):
    print(rowf.format(h_arr[i], cd[i]))
# Out:
# 1e-01 -0.0833052937077472
# 1e-02 -0.0833327690674679
# 1e-03 -0.0833309349856926
# 1e-04 -0.0832469149170123
# 1e-05 -0.0639432951032859
# 1e-06 5.9723892498197984
# 1e-07 -49.5381513587744848
# 1e-08 76278.4280183836963261
# 1e-09 -62505.5562863960949471
# 1e-10 -66613.3814775093924254
# 1e-11 -555111.5123125782702118

# %% [markdown]
# #### Step 3: Determine the equation for the derivative (by hand/WolframAlpha and then type in below this cell as markdown). Calculate the true value of the derivative at $x = 0.004$.

# %% [markdown]
# #### Step 4: Computationally compare your calculated answer to the true value for each $h$ value. Include a markdown explaining the process and result.

# %% [markdown]
# ## Automatic Differentiation
#
# Let's use the method of automatic differentation to determine the value for both the function
#
# $f(x) = x+\tan(\cos^2x+\sin^2x)$
#
# and its derivative at $x = 0$ (or at $t = 0$ as described in class). Do so using the following steps.
#
# a) Write a Python function `f(x)` to compute the function value and derivative of a list $x$ using automatic differentiation. [Hint: you will need a few additional functions as well -> look at the class notebook example]
#
# b) Make a plot of the function $f(x)$ vs. $x$ over the range of $-\pi$ to $\pi$ that you will be able to compare with your results in part c.
#
# c) Use your function determine the function and dervative values at $x = 0$ ($t=0$). Remember, that your list should be entered as `[t,1]`. How do you results compare with part b? Add a markdown cell to explain your process and compare your answer with your graph from part b.
#
#
# Hint: If you program is taking a long time to run, then you are probably doing the calculation the wrong way. It should only take a second or two to finish.

# %%
# part b

# %%
# part c
