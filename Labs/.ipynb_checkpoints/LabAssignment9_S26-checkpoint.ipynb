# %% [markdown]
# #### Name: Mason Miller

# %% [markdown]
# # PHYS 230 Lab Assignment 9
#
# ### Monday, February 23, 2026: Chapter 5.5-5.9
# - Evaluating integrals in python
#     - Gaussian Quadrature
#     - Infinite integrals
#     - Multiple integrals
#
# ***Don't forget to include comments in your code and a final markdown explanation at the end of each problem.***

# %%
# put all import statements here
import numpy as np
from gaussxw import gaussxw
import matplotlib.pyplot as plt

# %% [markdown]
# ## Gaussian Quadrature 1 (22 pts)
#
# Consider the integral from last lab $$\int_{1.1}^{10.1} \frac{\sin{x}}{\ln{x}} \,dx $$ a) Re-evaulate the integral using Gaussian quadrature with 𝑁=10 points
#
# b) Repeat the evaluation with 2𝑁 points and evaluate the error.
#
# c) Compare these results with your results for both the trapezoidal and Simpson’s rules

# %%
# part a
def A(x):
    return np.sin(x)/np.log(x) 

a = 1.1
b = 10.1
N = 10

xk, wk = gaussxw(N, a, b)

s1 = 0.0

for k in range(N):
    s1 += wk[k] * A(xk[k])

print(s1)
# Out:
# 2.7929415637242574

# %%
# part b

N = 20

xk, wk = gaussxw(N, a, b)

s2 = 0.0

for k in range(N):
    s2 += wk[k] * A(xk[k])

print(s2)

error = s2 - s1
print('The error is', error)
# Out:
# 2.84805880772841
# The error is 0.05511724400415252

# %% [markdown]
# # part c
#
# Trapezoid value with 200 steps: 2.8628779013854735\
# Simpsons value with 100 steps: 2.856855482008929\
# Gaussian value with 20 steps: 2.84805880772841
#
# It takes far fewer steps for the gaussian quadrature method to evaluate the integral.

# %% [markdown]
# ## Gaussian Quadrature 2 (22 pts)
#
# One of the caveats of Gaussian Quadrature is that the function being integrated must be relatively smooth. With this in mind, let’s integrate the function $$ f(x) = e^{-x^2/2}$$ from 𝑥=0 to 𝑥=1.5 using 2 sample points.
#
#
# a) First, make a plot of $f(x)$ vs. $x$ for 50 points within the limits of integration. Is this function smooth? Do we expect the method of GQ to return an accurate result?
#
# b) Determine and print out the values of the sample points and weights for this problem.
# Evaluate the integral.
#
# c) Double the number of sample points and apply parts (b) and (c) until your error is less than our desired accuracy of $10^{−5}$

# %%
# part a
# define the function
def f(x):
    return np.exp((-x**2)/2)

x = np.linspace(0, 1.5, 50)

plt.plot(x, f(x))

# %% [markdown]
# This function is quite smooth; i would expect gq to return a pretty accurate result.

# %%
# part b
# define a b and n
a = 0
b = 1.5
N = 2

xk, wk = gaussxw(N, a, b)
print('The sample points are', xk, 'with weights', wk)

s = 0.0
for k in range(N):
    s += wk[k] * f(xk[k])
print("The integral is", s)
# call this s I1 to evaluate error later
I1 = s
# Out:
# The sample points are [1.1830127 0.3169873] with weights [0.75 0.75]
# The integral is 1.0857790801898561

# %%
# part c
# double the number of points and evaluate the error

N = 4

xk, wk = gaussxw(N, a, b)

I2 = 0.0
for k in range(N):
    I2 += wk[k] * f(xk[k])
print("The integral is", I2)

# find error
error = I2 - I1
print(error)
# Out:
# The integral is 1.0858542826593234
# 7.52024694672393e-05

# %% [markdown]
# ## Gaussian Quadrature 3 (22 pts)
#
# Apply the method of Gaussian Quadrature to integrate the function $$f(x) = \sin\left(\frac{1}{x}\right)$$ from $𝑥=0.01$ to $x = 2\pi$. Do so in the via the following steps:
#
# a)  First, make a plot of $f(x)$ vs. $x$ for 50 points within the limits of integration. Is this function smooth? Do we expect the method of GQ to return an accurate result?
#
# b) Start with $N=5$ sample points & use a `while` loop to continue doubling $N$ until you achieve the accuracy you want (maybe $10^{-5}$). Comment on what happens each time you double.

# %%
# part a
# define the function
def f(x):
    return np.sin(1/x)
# create an array with our 50 points
x = np.linspace(0.01, np.pi*2, 50)
# plot
plt.plot(x, f(x))

# %% [markdown]
# This plot is not very smooth at all, so I dont expect gq to do a good job integrating

# %%
N = 5
a = 0.01
b = np.pi *2
while error < 10:
    # find the first integral
    xk, wk = gaussxw(N, a, b)
    s = 0.0
    for k in range(N):
        s += wk[k] * f(xk[k])
    I1 = s
    # double N
    N = N*2
    # find second integral
    xk, wk = gaussxw(N, a, b)
    s = 0.0
    for k in range(N):
        s += wk[k] * f(xk[k])
    I2 = s
    
    # find error
    error = np.abs(I2 - I1)
    print(error)

# %% [markdown]
# This code works... it is just taking loads of time? In the while loop, I calculate the integral with the first value of n, then double it and calculate the integral again. Then I find the error and print it. I think there might be a much better way to code this that is faster. But, my version should print out the error until that error is smaller than 10e-5.

# %% [markdown]
# ## Infinite integrals (22 pts)
#
# Let's evaluate the integral:
#
# $$ \int_0^\infty \frac{x^2}{\sqrt{x}}e^{-x}dx $$
#
# I don't want to do this by hand, so let's do it computationally.
#
# *Note: don't forget to put brief comments in your code*

# %% [markdown]
# #### Step 1: Define the variable substitution you will make for to solve this problem. This should be done in markdown using LaTex formatting.

# %% [markdown]
# $x = frac{z}{1-z}$ is what I will substitute. This means $dx = frac{dz}{(1-z)^2}$. $frac{x^2}{sqrt(x)}$ simplifies to x^3/2.

# %% [markdown]
# #### Step 2: Define the function to use in the next step for integration

# %%
# ill define this after substituting everything in 
def f(z):
    return (z/(1-z))**(3/2) * np.exp(-(z/(1-z))) * (1/(1-z)**2)

# %% [markdown]
# #### Step 3: Evaluate the integral using Gaussian Quadrature with 20 sample points

# %%
# do the same gaussian method weve used 
a = 0
b = 1
N = 20

xk, wk = gaussxw(N, a, b)

s = 0.0
for k in range(N):
    s += wk[k] * f(xk[k])
print(s)
# Out:
# 1.3293510592219389

# %% [markdown]
# #### Step 4: Include a markdown explaining the process and result. Include how your answer compares to the answer of $\frac{3\sqrt{\pi}}{4}$

# %% [markdown]
# I substitute \[x = frac{z}{1-z}]\ and \[dx = frac{dz}{(1-z)^2}]\ into the original integral. At that point, the bounds of integration become 0 to 1 and I just use gq method to evaluate the integral. My answer compared to 3 sqrt(pi) / 4 has a percent error of 8.0e-4%.

# %% [markdown]
# ## Multiple integrals (22 pts)
#
# Let's find the mass of a metal plate that is 3 meters wide (in the $x$ direction) and 2 meters tall ($y$ direction), with a nonuniform density of (in kg/$\text{m}^2$)
#
# $$ \sigma(x,y) = (\sin(\pi x)+1)y $$
#
# Hint 1: the total mass is given by: $$M = \iint_R \sigma(x,y) \hspace{1mm} dA$$
#
# *Note: don't forget to put brief comments in your code*

# %% [markdown]
# I am not going to be able to complete this section. It would go very similarly to the multiple integrals problem in todays class notebook. I would assign values for the x and y upper and lower bounds and the function, and then use gaussxw() do find the points and their weights and use a nested for loop to sum for the area in the bounded region.

# %% [markdown]
# #### Step 1: Write the full equation for the double integral in markdown. (Hint: you'll need to swithch the cell to markdown and then you can use some of my latex coding from the cell above this)

# %% [markdown]
# #### Step 2: Define the function to use in the next step for integration

# %% [markdown]
# #### Step 3: Evaluate the double integral using double Gaussian quadrature for 100 sample points along each axis.

# %% [markdown]
# #### Step 4: Include a markdown explaining the process and result. Include how your answer compares to the answer of $\frac{4}{\pi}+6 \simeq 7.2732395$
