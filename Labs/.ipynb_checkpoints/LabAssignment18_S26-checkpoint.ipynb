# %% [markdown]
# #### Name:

# %% [markdown]
# # PHYS 230 Lab Assignment 18
#
# ### Monday, April 13, 2026: Chapter 10.2
# - Monte Carlo Integration

# %%
# import statements here
import time
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## The problem: let's use Monte Carlo methods to evaluate the integral below.
# $$ f(x) = -x^3 +6x^2 -x+17 $$
# over the range of $ -2 \leq x \leq 5$

# %% [markdown]
# ## Part 1: "Hit-or-miss" Monte Carlo Method

# %% [markdown]
# #### Step 1: Make a plot of the function to get an idea of what it looks like.
#
# (**Hint:** After plotting, look at the $y$-axis and determine a reasonable $y_{\text{max}}$ for the axis limit and limit the axis between 0 and this determined value. This will help to define your area for the method.)

# %%
def f(x):
    return -x**3+6*x**2-x+17

domain = np.linspace(-2,5,1000)
fy = f(domain)
plt.scatter(domain,fy,color='red',s=1)
plot_f = plt.gca()
plot_f.set_ylim([0,52]) # decided that this would be the best option for a y-bound since it just barely doesn't cut off a portion of the graph
plt.show()

# %% [markdown]
# #### Step 2: Use your graph from step 1 to define the area over which you're evaluating your integral, and apply the "hit-or-miss" method of Monte Carlo integration for 10,000 points. Be sure to run the code a few times to get a sense of the average value returned.

# %%
start = time.time() # measured run time for later question, it's around 0.008-0.009 seconds
N = 10000
A = 7*52
s = 0
# initial values, and sets up summation variable

for i in range(N):
    x = 7*random.random()-2
    y = 52*random.random()
    if y < f(x):
        s += 1
# generates random points and checks if they are under the curve, incrementing summation variable for each hit

I10k = s*A/N # calculates integral using initial conditions and summation variable
end = time.time()
print(I10k, end-start)
# Out:
# 222.4404 0.009251832962036133

# %% [markdown]
# #### Step 3: You can fairly easily solve this integral by hand. Using code, evaluate the true integral below and compare it to your result from step 2.

# %%
def der_f(x):
    return -0.25*x**4+2*x**3-0.5*x**2+17*x

y2 = der_f(5)
y1 = der_f(-2)
print(y2-y1)
# solved for derivative equation by hand and plugged in endpoints
# Out:
# 222.25

# %% [markdown]
# #### Step 4: Try evaluating again using both fewer and more points (make sure you show both results). What do you notice about your result? What do you notice about these different results as you run the code multiple times? [To be really complete, try running for a variety of fewer and more points]

# %%
# these two programs are exactly the same as the program for step 2, except N is changed is different.
N = 1000
A = 7*52
s = 0

for i in range(N):
    x = 7*random.random()-2
    y = 52*random.random()
    if y < f(x):
        s += 1
I1k = s*A/N

print(I1k)
# Out:
# 226.408

# %%
N = 100
A = 7*52
s = 0

for i in range(N):
    x = 7*random.random()-2
    y = 52*random.random()
    if y < f(x):
        s += 1
I100 = s*A/N

print(I100)
# Out:
# 200.2

# %% [markdown]
# Returns a worse approximation of the correct value, variance between successive runs of the code is greater. Error and variance worsens as N decreases.

# %% [markdown]
# ## Part 2: Mean Value Method
#
# Let's evaluate the same integral using the mean value method instead.

# %% [markdown]
# #### Step 1: Define the function `f(x)` of the integrand

# %%
def g(x):
    return -x**3+6*x**2-x+17
# originally, I had overcomplicated this and so the function here was not the same as f(x) from step 1.
# f(x) and g(x) are entirely interchangeable now, I just haven't bothered to replace g with f

# %% [markdown]
# #### Step 2: Create a a loop with $N=10,000$ points to solve for the integral using the mean value method.

# %%
start2 = time.time() # the runtime here is around 0.007-0.008 seconds, it's shorter likely due to having to generate less random numbers and the if statement.
N = 10000
A = 7*52
k = 0
# sets up initial parameters and summation variable

for i in range(N):
    x2 = 7*random.random()-2
    k += g(x2)
# instead of counting the number of hits, this program just directly sums up the results of the equation, 
# as such the equation used to calculate the integral needs to be changed to match.
L = 7/N*k
end2 = time.time()
print(L, end2-start2)
# Out:
# 222.87054699134274 0.007172822952270508

# %% [markdown]
# #### Step 3: In a markdown cell, compare these results with the "hit-or-miss" method from above. What can you conclude about accuracy? speed? To really evaluate this, be sure to run each method with the same number of points multiple times to see the variation in the result.

# %%
N = 10000
A = 7*52
I_list = []
L_list = []
# sets up initial conditions, as well as two empty lists that this program uses to store results

for n in range(1000): # this performs the above methods 1000 times on the same integral, then stores the results in the empty lists
    s,k = 0,0
    for i in range(N):
        x3 = 7*random.random()-2
        y3 = 52*random.random()
        if y3 < f(x3):
            s += 1
    for i in range(N):
        x4 = 7*random.random()-2
        k += g(x4)
    I = s*A/N
    L = 7/N*k
    I_list.append(I)
    L_list.append(L)
# this part of the code is left separate from the code below for convenience, as it takes much longer to run than the rest of the program.

# %%
y2 = der_f(5)
y1 = der_f(-2)
I_actual = y2-y1
# computes actual value of integral to compare results to

# this goes through the two lists of stored results and calculates the percent error of each result, then stores it in another list
i2 = 0
err_I,err_L = np.zeros(len(I_list)),np.zeros(len(L_list))
while i2 < len(I_list):
    err_I[i2] = np.abs(100*(I_list[i2]-I_actual)/I_actual)
    i2 += 1
i2 = 0
while i2 < len(L_list):
    err_L[i2] = np.abs(100*(L_list[i2]-I_actual)/I_actual)
    i2 += 1

# sums up all values in the list of percent error and then averages the error for each list so that the two methods can be compared.
# could be optimized more by cutting out the intermediary lists of percent error and just summing them immediately.
err_I_sum = 0
for i3 in err_I:
    err_I_sum += i3
err_L_sum = 0
for i4 in err_L:
    err_L_sum += i4
err_I_avg = err_I_sum/len(err_I)
err_L_avg = err_L_sum/len(err_L)
    
print(err_I_avg, err_L_avg)
# Out:
# 0.6417612598425201 0.258428223260321

# %% [markdown]
# The error of the mean value method is lower than the hit or miss method. The mean value method also runs faster than the hit or miss method, by around 0.001 seconds.
