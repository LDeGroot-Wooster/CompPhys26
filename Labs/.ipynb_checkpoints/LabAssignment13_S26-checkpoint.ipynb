# %% [markdown]
# #### Name: Mason Miller

# %% [markdown]
# # PHYS 230 Lab Assignment 13
#
# ### Monday, March 9, 2026: Chapter 6, sections 3.5 - 3.8
# - Nonlinear equations - Newton's Method

# %%
# put all import statements here
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Newton's Method - single variable (22 pts)
#
# Solve the same problem from class used for binary search, but analyzed using Newton's Method instead.
# Find the roots of $$ f(x) = e^{x-\sqrt{x}}-x$$
#
# To do this:
#
# 1) Take the derivative by hand. You can use something like WolframAlpha to check your derivative. Write it in markdown.
#
# 2) Write two functions - `f(x)` that returns the result of the function for a given $x$ value and `df(x)` one that returns the derivative.
#
# 3) Make a plot of the function from $x=0$ to $x=5$. Use this to estimate the roots.
#
# 4) Apply the functions to find both roots.
#
# *You must clearly comment your code and include a markdown cell explaining your process*

# %% [markdown]
# #### part 1, thanks
# The derivative is:
#
# $$e^{x-\sqrt{x}}\left(1-\frac{1}{2\sqrt{x}}\right)-1 $$

# %%
# part 2
def f(x):
    return np.exp(x-np.sqrt(x)) - x

def df(x):
    return np.exp(x-np.sqrt(x)) * (1 - 1/(2*np.sqrt(x))) - 1

# %%
# part 3
# create array of x values
x = np.linspace(0,5,500)

# plot f(x) with a grid and x axis to estimate roots
plt.plot(x, f(x))
plt.axhline()
plt.grid()

# %% [markdown]
# There are roots at about 1 and 2.5

# %%
# part 4
# create guess array
x_guess = np.array([1.0, 2.5])

# save this array
x_0 = np.copy(x_guess)

# desired accuracy and initial error guess 
accuracy = 1e-11
err = 1.0

# while loop based on accuracy
while err > accuracy:
    # delta is the rise over run of the derivative at our initial guesses
    delta = f(x_guess)/df(x_guess)
    x_guess -= delta
    err = max(np.abs(delta))

print(x_guess)
print(x_0)
# Out:
# [1.         2.49090932]
# [1.  2.5]

# %% [markdown]
# The roots of $ f(x) = e^{x-\sqrt{x}}-x$ are 1 and 2.49. Using the plot, I guessed the first root correctly and was very close to the second. After defining the function and the derivative , I applied newtons rule. THe reason newtons rule works here is that the function is well behaved.

# %% [markdown]
# ## Newton's Method - many variables (22 pts)
# #### Adapted from Nonlinear Circuits (book exercise 6.18, pg. 276)
#
# Exercise 6.1 used regular simultaneous equations to solve for the behavior of circuits of resistors.  Resistors are linear---current is proportional to voltage---and the resulting equations we need to solve are therefore also linear and can be solved by standard matrix methods.  Real circuits, however, often include nonlinear components.  To solve for the behavior of these circuits we need to solve nonlinear equations.
#
# Consider the following simple circuit, a variation on the classic
# Wheatstone bridge:
#
# <img src="data:image/png;base64,..." width="200">
#
# We will use Newton's Method to solve for the voltages in the
# The resistors obey the normal Ohm law, but the diode obeys the diode equation:
# $$ I = I_0 (e^{V/V_T} - 1),$$
# where $V$ is the voltage across the diode and $I_0$ and $V_T$ are constants.
#
# The Kirchhoff current law says that the total net current flowing into or out of every point in a circuit must be zero.  Applying the law to voltage $V_1$ in the circuit above we get
# $$
# {V_1-V_+\over R_1} + {V_1\over R_2}
#   + I_0\bigl[e^{(V_1-V_2)/V_T} - 1\bigr] = 0.
# $$
#
#
# 1) In a markdown cell, derive the corresponding equation for voltage $V_2$.
#
# 2) Solve the two nonlinear equations for the voltages $V_1$ and $V_2$.
#
# 3) Use Newton's method to solve the equations. This means you need to first take the derivatives of each equation with respect to each variable (so you'll have 4 equations). Define the Jacobian matrix. Setup the matrix necessary to analyze using the `np.linalg.solve()` function. Apply the following conditions:
#
# $$\begin{align*}
# V_+ &= 5\,\textrm{V}, \\
# R_1 &= 1\,\mathrm{k}\Omega, \qquad
# R_2 = 4\,\mathrm{k}\Omega, \qquad
# R_3 = 3\,\mathrm{k}\Omega, \qquad
# R_4 = 2\,\mathrm{k}\Omega, \\
# I_0 &= 3\,\textrm{nA},\qquad
# V_T = 0.05\,\textrm{V}.
# \end{align*}$$
#
# 4) Apply the function to find both roots to solve for $V_1$ and $V_2$. The electronic engineer's rule of thumb for diodes is that the voltage across a (forward biased) diode is always about 0.6 volts. Confirm that your results agree with this rule by taking the difference between your results.
#
# *You must clearly comment your code and include a markdown cell explaining your process*

# %% [markdown]
# ### part 1
# As seen above, kirchoffs law for V1 is
# $$
# {V_1-V_+\over R_1} + {V_1\over R_2}
#   + I_0\bigl[e^{(V_1-V_2)/V_T} - 1\bigr] = 0.
# $$
#
# for V2, we get
#
# $$
# {V_2-V_+\over R_3} + {V_2\over R_4}
#   - I_0\bigl[e^{(V_1-V_2)/V_T} - 1\bigr] = 0.
# $$

# %%
# part 2 and 3
# define the two functions with v1 and v2 as the variables
def f(v1, v2):
    return (v1 - vplus)/R1 + v1/R2 + I*(np.exp((v1-v2)/v) - 1)

def g(v1, v2):
    return (v2 - vplus)/R3 + v2/R4 - I*(np.exp((v1-v2)/v) - 1)

# define our desired accuracy and initial guesses
accuracy = 100e-13
v1 = 1.0
v2 = 1.0

# initial error
err = 42

# define all of the variables and things
v = 0.05
R1 = 1e3
R2 = 4e3
R3 = 3e3
R4 = 2e3
I = 3e-9
vplus = 5

# while loop to end once desired accuracy is reached
while err > accuracy:
    # define the four equations of partial derivatives of f and g with respect to both v1 and v2
    # i did this on paper
    dv1f = 1/R1 + 1/R2 + (I/v)*np.exp((v1-v2)/v)
    dv2f =-(I/v)*np.exp((v1-v2)/v)
    dv1g = -(I/v)*np.exp((v1-v2)/v)
    dv2g = 1/R3 + 1/R4 + (I/v)*np.exp((v1-v2)/v)

    # create the jacobian matrix
    A = np.array([[dv1f, dv2f],
                  [dv1g, dv2g]])
    # create the array of functions
    V = np.array([f(v1, v2), g(v1, v2)])
    # use linalg to solve
    values = np.linalg.solve(A, V)
    print(values)

    subtract the value from the estimate
    v1 -= values[0]
    v2 -= values[1]

    err = np.sqrt(values[0]**2 + values[1]**2)
print(v1, v2)
# Out:
# [-2.99990401 -1.00014398]
# [ 0.02000315 -0.02999685]
# [ 0.01999953 -0.03000047]
# [ 0.01999182 -0.03000818]
# [ 0.0200039 -0.0299961]
# [ 0.02000184 -0.02999816]
# [ 0.01999951 -0.03000049]
# [ 0.02000022 -0.02999978]
# [ 0.01999999 -0.03000001]
# [ 0.02000006 -0.02999994]
# [ 0.01999999 -0.03000001]
# [ 0.02 -0.03]
# [ 0.02 -0.03]
# [ 0.02 -0.03]
# [ 0.02       -0.02999999]
# [ 0.01999999 -0.02999998]
# [ 0.01999996 -0.02999994]
# [ 0.01999989 -0.02999984]
# [ 0.01999969 -0.02999954]
# [ 0.01999911 -0.02999867]
# [ 0.01999746 -0.02999619]
# [ 0.01999275 -0.02998913]
# [ 0.01997937 -0.02996905]
# [ 0.01994143 -0.02991214]
# [ 0.01983441 -0.02975162]
# [ 0.01953542 -0.02930313]
# [ 0.01871988 -0.02807982]
# [ 0.01663124 -0.02494685]
# [ 0.01208737 -0.01813105]
# [ 0.00537674 -0.0080651 ]
# [ 0.0008373  -0.00125595]
# [ 1.73952187e-05 -2.60928280e-05]
# [ 7.30505397e-09 -1.09575817e-08]
# [ 1.38879614e-15 -1.69288143e-15]
# 3.4469546188585745 2.8295680717121385

# %%
# part 4
# find the difference between v1 and v2
difference = v1 - v2
print('The voltage across a diode is', difference)
# Out:
# The voltage across a diode is 0.6173865471464359

# %% [markdown]
# Our value for the voltage across the diode nearly agrees with the engineers rule, which is great. I applied Newtons method after finding the derivatives of both the v1 and v2 equation with respect to v1 and v2.
