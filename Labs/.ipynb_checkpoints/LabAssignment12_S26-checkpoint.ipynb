# %% [markdown]
# #### Name: Juno Ryan

# %% [markdown]
# # PHYS 230 Lab Assignment 12
#
# ### Wednesday, March 4, 2026: Chapter 6.3.1 - 6.3.4
# - Nonlinear equations part 1

# %%
# put all import statements here
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Relaxation Method - 2 variable (25  points)
#
# Use the relaxation method to solve for x and y in the following nonlinear equations:
#
# $$ 3x - \frac{1}{y} = -1 $$
# $$2x^2 - y = 0$$
#
# To do this:
# 1) First solve the first equation for $x$ and the second equation for $y$. Put this in a markdown cell.
#
# 2) Make an initial guess for $x$ and $y$ by thinking about one of the equations and determine number of iterations. Explain reasoning in markdown or commenting
#
# 3) Apply the relaxation method (check class notebook) via a user-defined function `relax_method(N,x,y)`. Call on your function and see if it works!
#
# 4) If it doesn't converge, try solving the inverse equations for $x$ and $y$ and try calling your relaxation method function again.
#
# *You must clearly comment your code and include a markdown cell explaining your process*

# %% [markdown]
# ##### Part 1 (double click cell to add your equation)
# $$x = \frac{-1+1/y}{3}$$ and $$y = 2x^2$$

# %%
# part 2
x = 1
y = 2
N = 20

# %%
#equation f1 for x(y) and equation f2 y(x)
def f1(y):
    return (-1+(1/y))/3
def f2(x):
    return 2*x**2

#function to perform relaxation method
def relax_method(N,x,y):
    #make empty lists and set the first value to current x/y value
    x_list = np.zeros(N+1, float)
    y_list = np.zeros(N+1, float)
    x_list[0] = x
    y_list[0] = y
    for k in range(N):
        x = f1(y) #calculates new values of x and y
        y = f2(x)
        x_list[k+1], y_list[k+1] = x, y #appends current values of x and y to list
    return x_list, y_list 

#Print arrays containing all values of x and y calculated in the loop
x_results = relax_method(N,x,y)[0]
y_results = relax_method(N,x,y)[1]
print("X results:", x_results, "Y results:", y_results)
# Out:
# X results: [ 1.         -0.16666667  5.66666667 -0.32814302  1.21449361 -0.22033858
#   3.09961809 -0.31598601  1.33588455 -0.23994107  2.56160664 -0.30793391
#   1.42432201 -0.25117864  2.30836572 -0.30205529  1.49340291 -0.25860337
#   2.15885229 -0.29757289  1.54885043] Y results: [2.00000000e+00 5.55555556e-02 6.42222222e+01 2.15355686e-01
#  2.94998947e+00 9.70981795e-02 1.92152646e+01 1.99694322e-01
#  3.56917506e+00 1.15143435e-01 1.31236572e+01 1.89646585e-01
#  4.05738637e+00 1.26181418e-01 1.06571046e+01 1.82474802e-01
#  4.46050449e+00 1.33751407e-01 9.32128642e+00 1.77099250e-01
#  4.79787533e+00]

# %%
#inverse equations for y and x
def f1(y):
    return np.sqrt(y/2)
def f2(x):
    return 1/(3*x+1)

x_results = relax_method(N,x,y)[0]
y_results = relax_method(N,x,y)[1]
print("X results:", x_results, "Y results:", y_results)
print("x converges to", x_results[-1], "and y converges to", y_results[-1])
# Out:
# X results: [1.         1.         0.35355339 0.49258572 0.44921643 0.46149648
#  0.45791756 0.458952   0.45865229 0.45873907 0.45871394 0.45872121
#  0.45871911 0.45871972 0.45871954 0.45871959 0.45871958 0.45871958
#  0.45871958 0.45871958 0.45871958] Y results: [2.         0.25       0.48528137 0.4035908  0.425958   0.41937699
#  0.42127388 0.42072385 0.42088306 0.42083695 0.4208503  0.42084644
#  0.42084756 0.42084723 0.42084733 0.4208473  0.42084731 0.4208473
#  0.4208473  0.4208473  0.4208473 ]
# x converges to 0.45871957913790984 and y converges to 0.4208473046242799

# %% [markdown]
# First I solved equation 1 for x and equation 2 for y. Looking at one of the results, $y = 2x^2$ I chose the values $x=1$ and $y=2$ to start. I chose 20 steps because in the notebook that always seemed to be more than enough to tell if something is going to converge. I defined two functions, one for x(y) and one for y(x). I then defined a function to perform the relaxation method. It uses a for loop to calculate new values of x and y by calling the two other functions, stores those new values in a list, and then repeats the process. The function retruns two lists, one of the x values and one of the y values, so it is easy to tell whether convergence is occuring. From part 3 it was clear that convergence was not occuring. So I solved equation 1 for y and equation 2 for x instead, and defined two new functions. When I called the relax_method function again, the system converged well within the 20 steps.

# %% [markdown]
# ## Binary Search (25 pts)
#
# Use the binary search method to find the roots of $f(x) = 5e^{-x} +x -5$.
#
# To do this:
# 1) Start by defining two functions: `f(x)` which returns the given function in the problem and `binary_solve(f,x1,x2,accuracy)` which applies the binary search method for a given function $f(x)$ based on two initial values $x_1, x_2$, and continues to iterate until a given accuracy is achieved.
#
# 2) Call the function and analyze the results. [Use a graph to estimate the interval that returns a non-zero $x$.]
#
# 3) Plot this point as a magenta star on the graph from step 2 to see if it agrees.
#
#
# *You must clearly comment your code and include a markdown cell explaining your process*

# %%
# part 1
def f(x): #define f(x)
    return (5*math.e**(-x))+x-5

def binary_solve(f, x1, x2, accuracy): #function to return x-value of root of f between x1 and x2
    #first, make sure one f(x) is positive and other negative. If not return 0
    if f(x1) > 0 and f(x2) < 0:
        pos_x = x1
        neg_x = x2
    elif f(x1) < 0 and f(x2) > 0:
        pos_x = x2
        neg_x = x1
    else:
        return 0
    #while difference between x's tested is greater than desired accuracy
    while np.abs(pos_x-neg_x) > accuracy:
        xprime = 0.5*(pos_x+neg_x) #calculate point in between tested x's
        fprime = f(xprime)  #find value of new point
        if fprime > 0:   #if positive use that as new positive bound
            pos_x = xprime
        elif fprime < 0:  #if negative use as new negative bound
            neg_x = xprime
        else:             #if 0 is a root! return
            return xprime
    return xprime          #return most recent halfway point when ideal accuracy acheived.

# %%
# part 2
x1 = 0.1
x2 = 10
x_result = binary_solve(f, x1, x2, 1e-6) #run binary_solve to find the root that's between 0 and 10
print(x_result)
# Out:
# 4.965114361047744

# %%
#values of function to plot
x_list = np.linspace(-2,20,100) 
f_list = np.zeros(len(x_list))
for i in range(len(x_list)):
    f_list[i] = f(x_list[i])

plt.grid()
plt.scatter(x_list, f_list, s = 15) #plot function
plt.scatter(x_result, f(x_result), s=200,color = 'magenta',marker='*') #plot found root
plt.show()

# %% [markdown]
# First I defined two functions, f and binary_solve. f is the given function. Binary solve performs binary search similarly to the function in the class notebook, except this time it has a while loop to acheive a desired accuracy. First, it finds which root is positive and which is negative. If both are positive or both are negative, the function fails to find a root and returns 0. Then it calculates the intermediate value x' and f(x'). If f(x') is positive, it becomes the new positive test value and same for negative. If desired accuracy is not yet acheived the process is repeated with the new values. To find good values to use I plotted 100 values of the function between -2 and 20. There is a clear root at 0 but also at approximately 5, so I used the range 0.1 to 10. Once I found the root, which is approximately 5 but not exactly (My small accuracy shows that the value is NOT equivalent to 5, just very close) I plotted it on the same graph.

# %% [markdown]
# ## Energy of an electron in a square potential well
#
# Consider a square potential well of width $w$, with walls of height $V$:
#
# <img src="data:image/png;base64,..." width="400">
#
# Using Schrödinger's equation, it can be shown that the allowed energies $E$ of a single quantum particle of mass $m$ trapped in the well are solutions of
# $$ \tan{\sqrt{w^2mE/2\hbar^2}} = \begin{cases}
# \sqrt{(V-E)/E} & \text{ for the even numbered states} \\
# -\sqrt{E/(V-E)} & \text{ for the odd numbered states}
# \end{cases}
# $$
#
# where the states are labeled with integers starting from 0 and working upward, the ground state being state 0, the first excited state being state 1, and so forth.
#
# a) For an electron of (mass $9.1094 \times 10^{-31}$ kg) in a well with $V = 20 \text{ eV}$ and $w = 1 \text{ nm}$, write a Python program to plot the three quantities
# $$y_1 = \tan{\sqrt{w^2mE/2\hbar^2}} \hspace{0.2in} y_2 = \sqrt{\frac{V-E}{E}} \hspace{0.2in} y_2 = -\sqrt{\frac{E}{V-E}}, $$
#
# on the same graph, as a function of $E$ from $E = 0$ to $E = 20 \text{ eV}$. **Hint** You may find it useful to define functions to calculate $y_1$, $y_2$, and $y_3$.
#
# b) From your plot make approximate estimates of the energies of the first six energy levels of the particle.
#
# c) Write a program to calculate the values of the first six energy levels in electron volts to an accuracy of $0.001 \text{ eV}$ using binary search.
#
# *hint, remember that energies need to be converted to joules in the $y_1$ equation above*
#
# *You must clearly comment your code and include a markdown cell explaining your process*

# %%
#a)
#define constants
width = 1e-9 #meters
V = 20 #eV
V_J = V*1.6022e-19 #J
mass = 9.1094e-31 #kg
planck = 1.0546e-34 #Js

#define equations for y1, y2, y3
def y1(E):
    E_J = E*1.6022e-19
    return np.tan(np.sqrt(width**2*mass*E_J/(2*planck**2)))

def y2(E):
    return np.sqrt((V-E)/E)

def y3(E):
    return -np.sqrt(E/(V-E))

#lists of 400 values to plot
E_list = np.linspace(0,20,400)
y1_list = np.zeros(len(E_list))
y2_list = np.zeros(len(E_list))
y3_list = np.zeros(len(E_list))

#populates list for y1, y2, y3
for i in range(len(E_list)):
    y1_list[i] = y1(E_list[i])
    if E_list[i] > 0: #y2 equation not valid for E=0
        y2_list[i] = y2(E_list[i]) 
    if E_list[i]<20: #y3 equation not valid for E=20
        y3_list[i] = y3(E_list[i])

#plot all 3 equations
plt.scatter(E_list, y1_list, s = 15, c = 'blue', label = 'y1')
plt.scatter(E_list, y2_list, s= 15, c = 'red', label = 'y2')
plt.scatter(E_list, y3_list, s = 15, c = 'green', label = 'y3')
plt.ylim(-20,20) #limit y-range for root visibility
plt.legend(fontsize = 10)
plt.grid()
plt.show()

# %%
#b)
#E_0 ~ 0.5 (1st excited state - even)
E0_left = 0.01
E0_right = 0.75
#E_1 ~ 1.5 (2nd excited state - odd)
E1_left = 0.75
E1_right = 2.5
#E_2 ~ 3 (3rd excited state - even)
E2_left = 2.5
E2_right = 3.0
#E_3 ~ 5 (4th excited state - odd)
E3_left = 3.0
E3_right = 6
#E_4 ~ 7.5 (5th excited state - even)
E4_left = 6
E4_right = 10.0
#E_5 ~ 11 (6th excited state - odd)
E5_left = 10.0
E5_right = 12.5

# %%
#c)
def binary_solve(x1, x2, state, accuracy): #function to return x-value of root of f between x1 and x2
    #Calculate center point between x1 and y1
    center_x = 0.5*(x1+x2)
    center_target = y1(center_x) #value of y1 at center point
    #f(center point) depends on whether odd or even
    if state%2 == 0:
        center_val = y2(center_x)
    elif state%2 == 1:
        center_val = y3(center_x)
        
    while np.abs(center_target-center_val) > accuracy: #how far off is y2(center) or y3(center) from y1(center)?
        if state%2 == 0: #even version
            #classify center x as either left bound or right bound depending on whether it is above or below value of y1
            if np.abs(center_val) > np.abs(center_target):
                x1 = center_x
            elif np.abs(center_val) < np.abs(center_target):
                x2 = center_x
            elif center_val == center_target: #if solution found
                return center_x
                
        elif state%2 == 1: #odd version
            if center_val > center_target:
                x1 = center_x
            elif center_val < center_target:
                x2 = center_x
            elif center_val == center_target:
                return center_x

        #recalculate center point, y1(center point) and y2/y3(center point)
        center_x = 0.5*(x1+x2)
        center_target = y1(center_x)
        if state%2 == 0:
            center_val = y2(center_x)
        elif state%2 == 1:
            center_val = y3(center_x)
    return center_x #return close enough solution once desired accuracy reached


E_0 = binary_solve(E0_left, E0_right, 0, 0.001)
E_1 = binary_solve(E1_left, E1_right, 1, 0.001)
E_2 = binary_solve(E2_left, E2_right, 2, 0.001)
E_3 = binary_solve(E3_left, E3_right, 3, 0.001)
E_4 = binary_solve(E4_left, E4_right, 4, 0.001)
E_5 = binary_solve(E5_left, E5_right, 5, 0.001)

print("E_0 =", E_0, "E_1 =", E_1 ,"E_1 =", E_1, "E_2 =", E_2, "E_3 =", E_3, "E_4 =", E_4, "E_5 =", E_5)
# Out:
# E_0 = 0.3179531860351562 E_1 = 1.26953125 E_1 = 1.26953125 E_2 = 2.85107421875 E_3 = 5.05078125 E_4 = 7.849609375 E_5 = 11.2158203125

# %% [markdown]
# In part a, I defined the three equations and needed constants, created arrays of their values at different Es, and plotted them. I used this plot to inform my bounds in part b. In part c, I defined a function that takes the two bounds from part b, a state (ground state = 0, 1st excited = 1, etc) and a desired accuracy and performs binary search. The goal is to find a point within the given bounds where the value of y1 is close enough to the value of y2 or y3 (depending on whether the state is even or odd). It does this using a while loop that continues to check accuracy, calculate a center value, and redefine that center value as a left or right bound depending on whether y2/y3 is greater or less than y1.
