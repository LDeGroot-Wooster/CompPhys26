# %% [markdown]
# #### Name: Therrin Baker

# %% [markdown]
# # PHYS 230 Lab Assignment 6
#
# ### Mondday, February 9, 2026: Chapter 3.4 + VPython
# - 3D graphics

# %% [markdown]
# #### Start by importing any packages you need below (feel free to update as you go):

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="vpython")

from vpython import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ## Catch the errors! (5 pts each)
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. add a new markdown cell that describes what was wrong with the code,<br>
#     b. creating a new code cell with the corrected code (where possible)<br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
#1 - create a 3D cone with the point pointing upwards 
scene_catch_the_errors_1 = canvas()
my_cone = cone(pos = vec(1,1,-1), axis=vec(0,5,0))
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# The code above needs to have it's input arguements for the cone function to be vectors, not lists. Additionally if they wish to display the cone, they need to call the canvas function.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> great! </font>

# %% [markdown]
# ## Short python snippets (5 pts each)
# Below each markdow cell, write a short python snippet to perform the indicated action; you will likely have to use google to find out how to perform some of these actions--this is deliberate on my part. Google and *stack overflow* are your friends.<br>
# Add a markdown cell to explain your thinking if this is needed.

# %% [markdown]
# 1. Create a helix with a length of 4 lying along the x-axis. Make the helix your favorite color (of those available).

# %%
scene_short_python_snippet_1 = canvas()
helix_short_python_snippet_1 = helix(pos=vec(0,0,0),axis=vec(5,0,0), color=vec(0.6,0,0.5)) #purple is my favorite!
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> nice color! can also center the helix if you want to using `pos = vector(-2,0,0)`</font>

# %% [markdown]
# ### Write a script (22 pts)
# #### Making 3D objects - making a table
#
# Write a code to do the following:
# - Create a scene that is 400 x 400 units (width x height)
# - Make a table using the following objects:
#     - 4 long cylinders for the legs
#         - the legs must be exactly under the corners of the table (not sticking out, not moved in)
#     - a box for the table top
# - Make the background white, the table red, and the legs blue
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
scene_write_a_script_1 = canvas(width=400,height=400, background=vec(1,1,1),autoscale=False)
Table_Width = 10
Table_Length = 8
Table_Height = 3
for i in range(2):
    for j in range(2):
        legs_of_table = cylinder(pos=vec(Table_Width/2*j,0,Table_Width/2*i),axis=vec(0,Table_Height,0),color=vec(0,0,0.5), radi=0.01)
body_of_table = box(pos=vec(Table_Width/4,Table_Height,Table_Width/4), length=Table_Length,width=Table_Width, color=vec(1,0,0))
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# First we define the scene with the canvas command, before using a nested for loops to define the four legs of the table, and then finally we define the body of the table.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'>good! legs aren’t quite long cylinders, a little stubby. Could you make them more flush with the edge of the table?
#
# <font color='red'> don't forget to comment in code</font>

# %% [markdown]
# ### Animation #1 (22 pts)
# #### A Growing Cone
#
# - Create a cone of some initial height and radius
# - Make it grow to 5 times it’s size
# - Use the appropriate rate to make this occur over 10 seconds
# - Make the cone a color of your choice
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
#scene_animation_1 = canvas()
scene_animation_1 = canvas(autoscale=False)
Growing_cone_radi = 1
Growing_cone_height = 1
Growing_cone = cone(pos=vec(0,0,0), axis=vec(1,1,1), radi=Growing_cone_radi, length=Growing_cone_height, color=vec(1,1,1))
for t in range(100): # Note that the range=100, and rate=10, so time ellapsed should be 100/10 = 10 seconds
    rate(10)
    Growing_cone_radi = 1+5*sin(np.pi * t / 50)
    Growing_cone_height = (1 + t/10)*(10/22)
    Growing_cone.radi = Growing_cone_radi 
    Growing_cone.length = Growing_cone_height
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# For the code above I start by defining the scene and the cone that will undergo growth. I them use a for loop, making the growing cone increase in overall volume to 5 times in size, by updating the values of the the radi and length in the for loop.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> your radius appears to get smaller as the cone grows taller?  and if I turn off autoscale (see how I commented out your canvas and added one without autoscale), then the radius doesn't change. Want both to change so the entire cone, to scale, changes over the time.
#
# <font color='red'> commenting or markdown explanation of radius and height growth would be helpful</font>

# %% [markdown]
# ### Animation #2 (22 pts)
# #### Animating 3D objects - a bouncing ball
#
# - Create a green sphere starting in the upper left corner of your scene
# - Make it zig-zag it across the scene from the upper left to the lower right, overall
# - Have it cross the screen at least 5 times
# - Have autoscale off
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
scene_animation_2 = canvas(autoscale=False)
zig_x = -10
zig_y = 7
sphere_zig_zag = sphere(pos=vec(zig_x,zig_y,0), color=vec(0,1,0))
for i in range(110):
    rate(10)
    if i%20<10:
        zig_x+=1
    else: zig_x-=1
    zig_y+= -0.12
    sphere_zig_zag.pos= vec(zig_x,zig_y,0)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# I start by defining the scene and the sphere. I then use a for loop to iterate the position of the sphere, making a zig-zag by using modulo arithematic, and in the for loop I update the position of the sphere.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'>doesn't quite make it all the way to the edges of your scene (only goes halfway across and doesn't start all the way in upper left corner). How could you make it start at the corner and end at the corner?  </font>

# %% [markdown]
# ### Animation #3 (22 pts)
# #### Animating 3D objects - a spinning sign
#
# - Create a new scene of your choice
# - Create a rectangular sign (large, flat box)
# - Make it rotate counter-clockwise smoothly
# - Have it continue to rotate CCW once every second for 5 seconds
#
# Note: The axis attribute may be helpful here!

# %%
scene_animation_3 = canvas(height=400,width=400,autscale=False)
recangular_sign = box(height=5,length=5,axis=vec(0,1,0),pos=vec(0,0,0))
for t in range(100): #Notice that we have frequency=1/50 and rate=50, so our time should be rate*frequency = 1 cycle/sec
    rate(50)
    recangular_sign.axis = vec(5*sin(-2*pi*t/50),5*cos(-2*pi*t/50),0)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# I start by defining the scene and the rectable. I then use a for loop to iteratively update the axis vector of the sign.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> you have a typo in your canvas for autoscale, so it actually does autoscale -> not a requirement so okay but good to be aware of. MOvement is a little choppy - how can you make it more smooth? </font>
