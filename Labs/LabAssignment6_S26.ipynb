# %% [markdown]
# #### Name:

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> You must enter your name here so I'm confident this is your work (-2 points)</font>

# %% [markdown]
# # PHYS 230 Lab Assignment 6
#
# ### Mondayday, February 9, 2026: Chapter 3.4 + VPython
# - 3D graphics

# %% [markdown]
# #### Start by importing any packages you need below (feel free to update as you go):

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="vpython")

from vpython import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ## Catch the errors! (5 pts each)
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. add a new markdown cell that describes what was wrong with the code,<br>
#     b. creating a new code cell with the corrected code (where possible)<br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
#1 - create a 3D cone with the point pointing upwards 
my_cone = cone(pos=[1,1,-1], axis=[0,5,0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 #1 - create a 3D cone with the point pointing upwards
# ----> 2 my_cone = cone(pos = (1,1,-1), axis=(0,5,0))
#
# File ~/Desktop/MiniConda/miniconda3/envs/suvpythenv/lib/python3.12/site-packages/vpython/vpython.py:1246, in cone.__init__(self, **args)
#    1244 args['_default_size'] = vector(1,2,2)
#    1245 args['_objName'] = "cone"
# -> 1246 super(cone, self).setup(args)
#
# File ~/Desktop/MiniConda/miniconda3/envs/suvpythenv/lib/python3.12/site-packages/vpython/vpython.py:668, in standardAttributes.setup(self, args)
#     666             else:
#     667                 if isinstance(val, vector): setattr(self, '_'+a, vector(val))  # '_' bypasses setters; copy of val
# --> 668                 else: raise AttributeError(a+' must be a vector')
#     669             del args[a]
#     671 # Track side effects of modifying size, axis, or up
#     672 # For consistency with GlowScript, axis is listed before up in the attrLists,
#     673 # so that setting axis may affect up, but then setting up can affect axis afterwards.
#
# AttributeError: pos must be a vector

# %% [markdown]
# The position must be a vector, so it needs () and it needs vector out infront. It also needs a canvas so you can see it.

# %%
canvas()
my_cone = cone(pos=vector(1,1,-1), axis=vector(0,5,0))
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> great! </font>

# %% [markdown]
# ## Short python snippets (5 pts each)
# Below each markdow cell, write a short python snippet to perform the indicated action; you will likely have to use google to find out how to perform some of these actions--this is deliberate on my part. Google and *stack overflow* are your friends.<br>
# Add a markdown cell to explain your thinking if this is needed.

# %% [markdown]
# 1. Create a helix with a length of 4 lying along the x-axis. Make the helix your favorite color (of those available).

# %%
scene1 = canvas()
my_helix = helix(pos=vector(0,0,0), axis= vector(0,0,0), radius = 1, coils=20, color=color.orange)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> nice tightly wound coild but doesn't necessarily have an axis length of 4, this is done either with `length` or with `axis = vector(0,4,0)`</font>

# %% [markdown]
# ### Write a script (22 pts)
# #### Making 3D objects - making a table
#
# Write a code to do the following:
# - Create a scene that is 400 x 400 units (width x height)
# - Make a table using the following objects:
#     - 4 long cylinders for the legs
#         - the legs must be exactly under the corners of the table (not sticking out, not moved in)
#     - a box for the table top
# - Make the background white, the table red, and the legs blue
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
scene2=canvas(

width=400,
height=400,
background=color.white
)

#table dimensions

table_len = 8.0
table_wid = 4.0
table_thic = 1.0

#leg dimensions

leg_h = 5.0
leg_rad = 0.5

#placing the table at y = 0

tab_place = vector(0, -table_thic/2,0)

#making the table
table = box(pos=tab_place, size=vector(table_len,table_thic,table_wid), color=color.red)


#placing the legs in the corners

leg_bottom_y = -(table_thic + leg_h)

leg1 = cylinder(pos=vector(table_thic-4, leg_bottom_y, table_wid/2), axis=vector(0,leg_h,0),radius=leg_rad, color=color.blue)
leg2 = cylinder(pos=vector(table_thic+2, leg_bottom_y, table_wid/2), axis=vector(0,leg_h,0),radius=leg_rad, color=color.blue)
leg3 = cylinder(pos=vector(table_thic+2, leg_bottom_y, table_wid-6), axis=vector(0,leg_h,0),radius=leg_rad, color=color.blue)
leg4 =  cylinder(pos=vector(table_thic-4, leg_bottom_y, table_wid-6), axis=vector(0,leg_h,0),radius=leg_rad, color=color.blue)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# I started off by defining the dimensions of the table and legs. I then put the table at y = 0 to make placing the legs easier. I then placed every leg under each corner of the table.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> good start! you have nice elements but your legs stick out from your table. They need to move in just a little bit.
#
# <font color='red'> I would make your scene all one line so it's not so hard to read. having so much white space can make it a bit messy</font>

# %% [markdown]
# ### Animation #1 (22 pts)
# #### A Growing Cone
#
# - Create a cone of some initial height and radius
# - Make it grow to 5 times it’s size
# - Use the appropriate rate to make this occur over 10 seconds
# - Make the cone a color of your choice
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
scene3 = canvas(width=400, height=400, autoscale=False, center=vector(6,2,0), range=10)

c = cone(pos=vector(5,0,0), axis=vector(0,4,0), radius=1, color=color.blue)

#All I got done in lab, I struggled with these :(
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> good start! now just need to figure out how to animate! Since you didnt get any animation done, you really should come back to this </font>

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> You should really try these others though. </font>

# %% [markdown]
# ### Animation #2 (22 pts)
# #### Animating 3D objects - a bouncing ball
#
# - Create a green sphere starting in the upper left corner of your scene
# - Make it zig-zag it across the scene from the upper left to the lower right, overall
# - Have it cross the screen at least 5 times
# - Have autoscale off
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %% [markdown]
# ### Animation #3 (22 pts)
# #### Animating 3D objects - a spinning sign
#
# - Create a new scene of your choice
# - Create a rectangular sign (large, flat box)
# - Make it rotate counter-clockwise smoothly
# - Have it continue to rotate CCW once every second for 5 seconds
#
# Note: The axis attribute may be helpful here!
