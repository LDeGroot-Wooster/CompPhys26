# %% [markdown]
# #### Name:

# %% [markdown]
# # PHYS 230 S26 Lab Assignment 1
#
# ### Wednesday, January 21st: Chapter 2.1-2.3
# - Intro to Jupyter
# - Basics: variables & types
# - Output & input statements
# - Controlling programs: if & while statements
#
# **Be sure to include comments in your code**

# %% [markdown]
# ## Jupyter Notebooks & The Basics
#
# Jupyter notebooks are web-based and keep a history of input, output, text, and images.
# - important: When you work through a notebook, everything you did in previous cells is still in memory and known by python, so you can refer to functions and variables that were previously defined.
# - Even if you go up to the top of a notebook and insert a cell, all the information done earlier in your notebook session is still defined—it doesn’t matter where physically you are in the notebook. If you want to reset things, you can use the options under the Kernel menu.
#
# These notebooks use cells, which can be run individually. There are two types of cells: markdown and code
# - a markdown cell allows you to enter text with different formatting to explain what the notebook is doing.
# - a code cell is where you enter python code and run it
#
# To change between cell types, you can use the menu at the top.
#
# To run a cell, you can also use the menu buttons above or use the following shortcuts:
# - shift+enter = run cell and jump to the next (creating a new cell if there is no other new one)
# - ctrl+enter = run cell-in place
# - alt+enter = run cell and insert a new one below

# %% [markdown]
# ### Jupyter notebook practice (10 pts)
#
# - Insert a new cell below this one
# - In that cell, complete the classic example of printing "Hello World"

# %% [markdown]
# ### Markdown Practice (10 pts)
# You can also use markdown cells to typeset LaTeX equations in your notebook. You just need a single or double dollar sign around the equation.
#
# Your task: convert the cell below into a markdown cell and type the following equation, using LaTeX formatting, for a damped harmonic oscillator into it: $$x(t) = Ae^{-\beta t}\cos{(\omega_1t - \delta)}$$

# %% [markdown]
# $$x(t)=A\text{e}^{-\beta t}\cos{\left(\omega_{1}t-\delta\right)}$$

# %% [markdown]
# ## Catch the errors! (20 pts - 5 pts each)
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. add a new markdown cell that describes what was wrong with the code,<br>
#     b. creating a new code cell with the corrected code (where possible) - do not edit the given cell <br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
#1
z = x + y
x = 6
y = 8
print(z)
# Out:
# 14

# %% [markdown]
# For the code above, the problem is that as python reads left to right (and then down), python tries (and fails) to calculate $z = x + y$ (notice that x and y are not defined). So our solution to this error is just moving that line after $x$ and $y$ are defined but not after the print.

# %%
#1 Solution
x = 6
y = 8
z = x + y
print(z)
# Out:
# 14

# %%
#2
x = 10; y = 7
z = x y
# Out:
#   Cell In[7], line 3
#     z = x y
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# The problem for the code above is that there is no operation for $z = x~~y$. The user likely wanted $x$ times $y$, which we accomplish with the * operation. I also addded a print so that we can see the output.

# %%
#2 Solution
x = 10; y = 7
z = x*y
print(z)
# Out:
# 70

# %% [markdown]
# In the cell below (#3), the student wants to calculate the following:
# $$ z = \left( \frac{x+y}{5x}\right)^3 $$

# %%
#3
x = 12
y = 5
z = x+y/5*x^3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 x = 12
#       3 y = 5
# ----> 4 z = x+y/5*x^3
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %% [markdown]
# Notice that we actually have multiple problems here. We have the wrong type formatting of our operation (^ needs to be ** for exponentiation), but changing that will still give a wrong solution as we also have to pay attention to the order of operations used by python.

# %%
#3 Solution
x = 12.0
y = 5.0
z = (x+y)/(5*x**3)
print(z)
# Out:
# 0.0019675925925925924

# %%
#4
print(sin(pi))

# %% [markdown]
# There are multiple problems here, but mainly it is that they have not imported the math package as well as using the package prefixes.

# %%
#4 Solution
import math as m
print(m.sin(m.pi))
# Out:
# 1.2246467991473532e-16

# %% [markdown]
# ### Write a script 1 (22 pts)
# #### Even number or odd number?
#
# In the cell below, write code to do the following:
# - Ask the user for an integer
# - Determine if the integer is even or odd
# - If the number is even, do the following:
#     - while the number remains even, tell us that it is even, and divide by 2
# - if the number is odd, have the program print something that is funny to you (i.e., "I don't like odd numbers")
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
Num = int(input("Please provide a number. "))
i=0
if Num%2 == 0:
    while Num%2 == 0:
        i=i+1
        Num = Num/2
        if i==1:
            print("Your Number is even.")
        else:
            print("Your Number divided by 2",i, "times is even.")
else: print("Your Number is odd.")
# Out:
# Your Number is even.
# Your Number divided by 2 2 times is even.
# Your Number divided by 2 3 times is even.

# %% [markdown]
# ### Write a script 2 (22 pts)
# #### Quantum Potential Step
# A well-known quantum mechanics problem involves a particle of mass $m$ that encounters a one-dimensional potential step, like this:
#
# <img src="data:image/png;base64,..."  width="30%" />
#
# The particle with initial kinetic energy $E$ and wavevector $k_1 = \sqrt{2mE}/\hbar$ enters from the left and encounters a sudden jump in potential energy of height $V$ at position $x = 0$. By solving the Schrödinger equation, one can show that when $E > V$ the particle may either (a) pass the step, in which case it has a lower kinetic energy of $E - V$ on the other side and a correspondingly smaller wavevector of $k_2 = \sqrt{2m(E_V)}/\hbar$, or (b) it may be reflected, keeping all of its kinetic energy and an unchanged wavevector but moving in the opposite direction. The probabilities $T$ and $R$ for transmission and reflection are given by:
#
# $$T = \frac{4k_1k_2}{(k_1+k_2)^2} \hspace{2cm} R = \left(\frac{k_1-k_2}{k_1+k_2}\right)^2 $$
#
# Suppose we have a particle with mass equal to the electron mass $m = 9.11 \times 10^{-31} $ kg encountering a potential step of height, given by the user. In the cell below , write code to do the following:
#
# - Define all necessary constants assuming an electron with an energy of 10 eV.
# - Ask the user for the height of the potential step (in eV) encountered by the electron (perhaps noting that $E > V$).
# - Compute and print out the transmission and reflection probability using the formulas above.
# - Run your program multiple times with different potential steps to make sure the program returns the correct answers. Include your output from the each iteration in a markdown cell.
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
#Define constants
mass = 9.11*10**(-31) #Kg
h_bar =  6.58*10**(-16) #eV.s
Energy = 10 #eV

#Ask user for potential
Potential = float(input("What is the potential step the electron experiences (in electron volts)? ")) #eV

#Calculate wave numbers
k_1 = m.sqrt(2*mass*Energy)/h_bar #rad.m^-1
k_2 = m.sqrt(2*mass*(Energy-Potential))/h_bar #rad.m^-1

#Calculate Probabilities
Probability_Transmission = (4 * k_1 * k_2) / ((k_1 + k_2)**2) #Probability
Probability_Reflection = ((k_1 - k_2)**2) / ((k_1 + k_2)**2) #Probability

#Print Probabilities
print("Probability of transmission is:", Probability_Transmission)
print("Probability of reflection is:", Probability_Reflection)
# Out:
# Probability of transmission is: 0.9705627484771407
# Probability of reflection is: 0.02943725152285943

# %% [markdown]
# So the first thing that I did is define our constants (mass, reduced planck's constant, and the electron energy). The second thing I did was ask the user for the potential (in electron volts), before using it and previously defined constants to calculate our wave numbers. I put the calculation of the wave numbers next to each other so the code is more organized, and easier to correct potential errors. I then calculated the probabilities of transmission and reflection before printing the results. I also made sure to put the units next to every defined variable for more clarity.

# %% [markdown]
# NOTE

# %% [markdown]
# I ran out of time here, and was unable to finish the last problem.
#
# But, I would go about the last problem by:
# 1. asking for user input for magnitude and direction of the forces and then mass (so a total of 5 inputs)
# 2. Convert the forces from radial to cartesian using Fcos() and Fsin() for each Force. (we would then have F_x1 F_y1 & F_x2 F_y2)
# 3. Add the x components and the y components separately. This would result in F_netx and F_nety
# 4. Use math package sqrt(F_netx^2 + F_nety^2) and atan2(F_nety,F_netx) for magnitude of the net force and the direction.
# 5. Lastly I would divide the magnitude of the net force by mass to find the acceleration.

# %% [markdown]
# ### Write a script 3 (22 pts)
# #### Find the force components & direction of motion
#
# In the cell below, write code to do the following:
# - Ask the user for the mass of an object and for two forces acting on it, magnitude and direction (angle measured relative to the $+x$-axis)
# - Determine the x and y components of the forces
# - Determine the net force (magnitude and direction)
# - Determine the magnitude and direction of the net acceleration & print it for the user (magnitude and direction)
#      - Becareful with how you state the direction!
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
import math as m 
mass = float(input("Mass? "))
F_1r = float(input("Force 1 magnitude? "))
F_1rad = float(input("Force 1 angle (radians)? "))
F_2r = float(input("Force 2 magnitude? "))
F_2rad = float(input("Force 2 angle (radians)? "))

F1_x = F_1r * m.cos(F_1rad)
F1_y = F_1r * m.sin(F_1rad)
F2_x = F_2r * m.cos(F_1rad)

FN_x = F1_x+F2_x
FN_y = F1_y+F2_y

FN_r = m.sqrt(FN_x**2 + FN_y**2)
FN_rad = m.atan2(FN_y,FN_x)

a_r = m.sqrt(FN_x**2 + FN_y**2) / mass
a_rad = FN_rad

print(a_r)
print(a_rad)

#Quickly written code last minute
# Out:
# 2.0
# 1.0
