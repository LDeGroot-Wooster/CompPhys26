# %% [markdown]
# #### Name: W Lindelow

# %% [markdown]
# ### <font color='red'> For future labs, please don't rename the file -> keep it the same name as it is in the GitHub repo </font>

# %% [markdown]
# # PHYS 230 S26 Lab Assignment 1
#
# ### Wednesday, January 21st: Chapter 2.1-2.3
# - Intro to Jupyter
# - Basics: variables & types
# - Output & input statements
# - Controlling programs: if & while statements
#
# **Be sure to include comments in your code**

# %% [markdown]
# ## Jupyter Notebooks & The Basics
#
# Jupyter notebooks are web-based and keep a history of input, output, text, and images.
# - important: When you work through a notebook, everything you did in previous cells is still in memory and known by python, so you can refer to functions and variables that were previously defined.
# - Even if you go up to the top of a notebook and insert a cell, all the information done earlier in your notebook session is still defined—it doesn’t matter where physically you are in the notebook. If you want to reset things, you can use the options under the Kernel menu.
#
# These notebooks use cells, which can be run individually. There are two types of cells: markdown and code
# - a markdown cell allows you to enter text with different formatting to explain what the notebook is doing.
# - a code cell is where you enter python code and run it
#
# To change between cell types, you can use the menu at the top.
#
# To run a cell, you can also use the menu buttons above or use the following shortcuts:
# - shift+enter = run cell and jump to the next (creating a new cell if there is no other new one)
# - ctrl+enter = run cell-in place
# - alt+enter = run cell and insert a new one below

# %% [markdown]
# ### Jupyter notebook practice (10 pts)
#
# - Insert a new cell below this one
# - In that cell, complete the classic example of printing "Hello World"

# %%
x = 'Hello World!'
print(x)
# Out:
# Hello World!

# %% [markdown]
# ### Markdown Practice (10 pts)
# You can also use markdown cells to typeset LaTeX equations in your notebook. You just need a single or double dollar sign around the equation.
#
# Your task: convert the cell below into a markdown cell and type the following equation, using LaTeX formatting, for a damped harmonic oscillator into it: $$x(t) = Ae^{-\beta t}\cos{(\omega_1t - \delta)}$$

# %% [markdown]
# $ x(t) = Ae^{-\beta t}\cos(\omega_1 t - \delta) $

# %% [markdown]
# ### <font color='red'> Comments </font>
# <font color='red'> To center equation, use $$ instead of $ at beginning and end of your equation. That will make your equation identical to mine  </font>

# %% [markdown]
# ## Catch the errors! (20 pts - 5 pts each)
#
# For each of the following cells, find the error (or errors), and correct it (or them) by:<br>
#     a. add a new markdown cell that describes what was wrong with the code,<br>
#     b. creating a new code cell with the corrected code (where possible) - do not edit the given cell <br>
# <br>
# **Make sure to write in complete sentences; corrected code with a poorly written explanation will not receive better than 4 of 5 points on a given question.** I am not looking for a lengthy explanation; but one that is sufficiently detailed to explain the errors.

# %%
#1
z = x + y
x = 6
y = 8
print(z)
# Out:
# 0

# %% [markdown]
# The variables x and y are being defined after the equation they are being referenced in, leading to the operation failing.

# %%
x_2 = 6
y_2 = 8
z_2 = x_2 + y_2

print(z_2)
# Out:
# 14

# %%
#2
x = 10; y = 7
z = x y
# Out:
#   Cell In[14], line 3
#     z = x y
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Added a print command to make the code easier to debug. Since there is no operation being performed on the variables in the initial code, I assumed multiplication was the intended operation.

# %%
x_3 = 10; y_3 = 7
z_3 = x_3*y_3

print(z_3)
# Out:
# 70

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> good! we can also make this more efficient by defining x and y slightly differntly:
#
# x,y = 10, y</font>

# %% [markdown]
# In the cell below (#3), the student wants to calculate the following:
# $$ z = \left( \frac{x+y}{5x}\right)^3 $$

# %%
#3
x = 12
y = 5
z = x+y/5*x^3

# %% [markdown]
# Added a print command to make the code easier to debug. Uses a caret for exponentiation instead of two asterisks. Equation is programmed such that it doesn't perform the proper order of operations of the equation above, instead being equivalent to $ z = x^3 x \frac{y}{5} $. To ensure that order of operations is followed properly, the equation can be broken into multiple pieces.

# %%
import math
x = 12
y = 5
step_1 = x + 5
step_2 = 5 * x
step_3 = step_1 / step_2
z_1 = step_3 ** 3


print(z_1)
# Out:
# 0.022745370370370367

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> this definitely works, but you can also use parentheses to help with order of operations:
#
# z_1 = ((x+y)/(5*x))**3 </font>

# %%
#4
print(sin(pi))

# %% [markdown]
# Code doesn't import the math package, so there is no defined sine function or value of pi for this code to reference. I think value of pi in the math package is not exact, since this should just return zero.

# %%
import math

print(math.sin(math.pi))
# Out:
# 1.2246467991473532e-16

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> it's not that the value of pi is not exact, it's a floating point issue in python. We'll talk about this in a future chapter. However, 10^-16 is pretty close to zero! </font>

# %% [markdown]
# ### Write a script 1 (22 pts)
# #### Even number or odd number?
#
# In the cell below, write code to do the following:
# - Ask the user for an integer
# - Determine if the integer is even or odd
# - If the number is even, do the following:
#     - while the number remains even, tell us that it is even, and divide by 2
# - if the number is odd, have the program print something that is funny to you (i.e., "I don't like odd numbers")
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
x = int(input("Input an integer:"))
div_x = x / 2
rdiv_x = round(div_x)
if (rdiv_x == div_x):
    print(x, 'is even, and when divided by 2 becomes', int(div_x))  
else:
    print(x, 'is odd. Input a better number next time.')
# Out:
# 7 is odd. Input a better number next time.

# %% [markdown]
# The code works by dividing the input integer in half and then rounding it to the nearest integer. If the input integer is even, the rounding function will do nothing, and the rounded value will equal half the input integer. If the input integer is odd, rounding the non-integer result of dividing it by two will give a different value than half the input value. By comparing the rounded value to the halved input, the program can determine whether the input integer is even or odd.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> This is a very intersting approach. A more efficient method would be the modulo operator (%), but this does work for checking odd vs. even. however, you are missing the part that says "while it remains even...", which means that the division needs to keep happening until it is odd.
#
# Make sure you put comments in your code as well. </font>

# %% [markdown]
# ### Write a script 2 (22 pts)
# #### Quantum Potential Step
# A well-known quantum mechanics problem involves a particle of mass $m$ that encounters a one-dimensional potential step, like this:
#
# <img src="data:image/png;base64,..."  width="30%" />
#
# The particle with initial kinetic energy $E$ and wavevector $k_1 = \sqrt{2mE}/\hbar$ enters from the left and encounters a sudden jump in potential energy of height $V$ at position $x = 0$. By solving the Schrödinger equation, one can show that when $E > V$ the particle may either (a) pass the step, in which case it has a lower kinetic energy of $E - V$ on the other side and a correspondingly smaller wavevector of $k_2 = \sqrt{2m(E-V)}/\hbar$, or (b) it may be reflected, keeping all of its kinetic energy and an unchanged wavevector but moving in the opposite direction. The probabilities $T$ and $R$ for transmission and reflection are given by:
#
# $$T = \frac{4k_1k_2}{(k_1+k_2)^2} \hspace{2cm} R = \left(\frac{k_1-k_2}{k_1+k_2}\right)^2 $$
#
# Suppose we have a particle with mass equal to the electron mass $m = 9.11 \times 10^{-31} $ kg encountering a potential step of height, given by the user. In the cell below , write code to do the following:
#
# - Define all necessary constants assuming an electron with an energy of 10 eV.
# - Ask the user for the height of the potential step (in eV) encountered by the electron (perhaps noting that $E > V$).
# - Compute and print out the transmission and reflection probability using the formulas above.
# - Run your program multiple times with different potential steps to make sure the program returns the correct answers. Include your output from the each iteration in a markdown cell.
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
import math
E = 10
m = 9.109 * (10**(-31))
h_bar = 6.582 * (10**(-16))
V = float(input('Potential step in eV, must be lower than 10 eV for meaningful results:'))

k_1 = ((math.sqrt(2 * m * E)) / h_bar)
k_2 = ((math.sqrt(2 * m * (E - V))) / h_bar)

T = (4 * k_1 * k_2) / ((k_1 + k_2) ** 2)
R = ((k_1 - k_2) / (k_1 + k_2)) ** 2

print('Probability of transmission:', T)
print('Probability of reflection:', R)
# Out:
# Potential step in eV, must be lower than 10 eV for meaningful results: 7
# Probability of transmission: 0.9146067327078853
# Probability of reflection: 0.08539326729211469

# %% [markdown]
# V = 3 | T = 0.992 | R = 0.008
# V = 5 | T = 0.970 | R = 0.029
# V = 7 | T = 0.915 | R = 0.085
# V = 9 | T = 0.730 | R = 0.270
#
# Program takes the input potential step and the known constants and calculates the wavevectors of the electron before and after passing the potential step, uses those to calculate the probability of transmission and reflection, then prints them out in decimal form.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> Remember you only need to import math once in the entire notebook. Good job! just need to comment within code.
#
#   </font>

# %% [markdown]
# ### Write a script 3 (22 pts)
# #### Find the force components & direction of motion
#
# In the cell below, write code to do the following:
# - Ask the user for the mass of an object and for two forces acting on it, magnitude and direction (angle measured relative to the $+x$-axis)
# - Determine the x and y components of the forces
# - Determine the net force (magnitude and direction)
# - Determine the magnitude and direction of the net acceleration & print it for the user (magnitude and direction)
#      - Becareful with how you state the direction!
#
# When your program is complete, add a markdown cell below it to explain your process and program.

# %%
import math
m = float(input('Object mass:'))
f_1 = float(input('Magnitude of force 1:'))
theta_1 = math.radians(float(input('Angle of force 1 relative to +x-axis:')))
f_2 = float(input('Magnitude of force 2:'))
theta_2 = math.radians(float(input('Angle of force 2 relative to +x-axis:')))

fx_1 = f_1 * math.cos(theta_1)
fy_1 = f_1 * math.sin(theta_1)
fx_2 = f_2 * math.cos(theta_2)
fy_2 = f_2 * math.sin(theta_2)

fx_n = fx_1 + fx_2
fy_n = fy_1 + fy_2

f_n = math.sqrt(x**2 + y**2)
a_n = (m / f_n)
theta_n = math.atan(fy_n / fx_n)
theta_n_deg = math.degrees(theta_n)


print("The object is accelerating at", a_n, "meters per second, in a direction", theta_n_deg, "degrees from the positive x-axis.")
# Out:
# The object is accelerating at 5.812381937190964 meters per second, in a direction 1.2114041855236652 degrees from the positive x-axis.

# %% [markdown]
# The code requests all five required variables, calculates the force components based on the provided information, adds the components together to get the endpoint coordinates of the net force vector, then converts those back to radial coordinates and prints them.

# %% [markdown]
# ### <font color='red'> Comments </font>
#
# <font color='red'> Good, but be careful with direction - what if net force was negative in one of the directions? do you get the right answer every time?
#
# Need to comment within code.
#
#   </font>
